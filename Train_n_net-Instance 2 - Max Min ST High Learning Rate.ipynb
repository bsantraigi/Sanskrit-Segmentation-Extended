# %%
# %load_ext autoreload
# %autoreload 2

# %%
## bUILT-iN pACKAGES
import sys, os, time, bz2, zlib, pickle, math, json
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True)
# %matplotlib inline
from IPython.display import display

## lAST sUMMER
from romtoslp import *
from sentences import *
from DCS import *
import MatDB
from heap_n_PrimMST import *


## lAST yEAR
# from word_definite import *
from nnet import *
# from heap_n_PrimMST import *
# from word_definite import *

# %%
import winsound
def playBeep():
    for i in range(3):
        winsound.Beep(2200, 300)
        winsound.Beep(2600, 300)

# %%
loaded_SKT = pickle.load(open('../Simultaneous_CompatSKT_10K.p', 'rb'), encoding=u'utf-8')
loaded_DCS = pickle.load(open('../Simultaneous_DCS_10K.p', 'rb'), encoding=u'utf-8')

# %%
# dataset_4k_1k = pickle.load(open('../SmallDataset_4K_1K.p', 'rb'))
# TrainFiles = dataset_4k_1k['TrainFiles']
# TestFiles = dataset_4k_1k['TestFiles']

# dataset_6k_3k = pickle.load(open('../SmallDataset_6K_3K.p', 'rb'))
# TrainFiles_2 = dataset_6k_3k['TrainFiles']
# TestFiles_2 = dataset_6k_3k['TestFiles']

# %%
# matDB = MatDB.MatDB()

# %%
loader = pickle.load(open('../bz2Dataset_10K.p', 'rb'))
TrainFiles = loader['TrainFiles']
TestFiles = loader['TestFiles']
print(len(TrainFiles))
print(len(TestFiles))
def open_dsbz2(filename):
    with bz2.BZ2File(filename, 'r') as f:
        loader = pickle.load(f)
    
    conflicts_Dict_correct = loader['conflicts_Dict_correct']
    nodelist_to_correct_mapping = loader['nodelist_to_correct_mapping']
    nodelist_correct = loader['nodelist_correct']
    featVMat_correct = loader['featVMat_correct']
    featVMat = loader['featVMat']
    conflicts_Dict = loader['conflicts_Dict']
    nodelist = loader['nodelist']
    
    return (nodelist_correct, conflicts_Dict_correct, featVMat_correct, nodelist_to_correct_mapping,\
            nodelist, conflicts_Dict, featVMat)
# Out:
# 4046
# 4047

# %%
# from MatDB import *
import word_definite as WD
from heap_n_PrimMST import *
from nnet import *

# %%
"""
################################################################################################
######################  CREATE SEVERAL DATA STRUCTURES FROM SENTENCE/DCS  ######################
###########################  NODELIST, ADJACENCY LIST, GRAPH, HEAP #############################
################################################################################################
"""
def GetTrainingKit(sentenceObj, dcsObj):
    nodelist = GetNodes(sentenceObj)
    
    # Nodelist with only the correct_nodes
    nodelist2 = GetNodes(sentenceObj)
    nodelist2_to_correct_mapping = {}
    nodelist_correct = []
    search_key = 0
    first_key = 0
    for chunk_id in range(len(dcsObj.lemmas)):
        while nodelist2[first_key].chunk_id != chunk_id:
            first_key += 1
        for j in range(len(dcsObj.lemmas[chunk_id])):
            search_key = first_key
            while (nodelist2[search_key].lemma != rom_slp(dcsObj.lemmas[chunk_id][j])) or (nodelist2[search_key].cng != dcsObj.cng[chunk_id][j]):
                search_key += 1
                if search_key >= len(nodelist2) or nodelist2[search_key].chunk_id > chunk_id:
                    break
    #         print((rom_slp(dcsObj.lemmas[chunk_id][j]), dcsObj.cng[chunk_id][j]))
    #         print(nodelist[search_key])
            nodelist2_to_correct_mapping[len(nodelist_correct)] = search_key
            nodelist_correct.append(nodelist2[search_key])
    return (nodelist, nodelist_correct, nodelist2_to_correct_mapping)
    

def GetGraph(nodelist, neuralnet):
    if not neuralnet.outer_relu:
        conflicts_Dict = Get_Conflicts(nodelist)

        featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)

        (WScalarMat, SigmoidGateOutput) = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        return (conflicts_Dict, featVMat, WScalarMat, SigmoidGateOutput)
    else:
        conflicts_Dict = Get_Conflicts(nodelist)

        featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)

        WScalarMat = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        return (conflicts_Dict, featVMat, WScalarMat)

# %%
trainingStatus = defaultdict(lambda: bool(False))

# %%
"""
################################################################################################
##############################  TRAIN FUNCTION  ################################################
################################################################################################
"""

def train_generator(loaded_SKT, loaded_DCS, n_trainset = -1, iterationPerBatch = 10, filePerBatch = 20, _debug = True):
    # Train
    if n_trainset == -1:
        n_trainset = len(TrainFiles)
        totalBatchToTrain = math.ceil(n_trainset/filePerBatch)
    else:
        totalBatchToTrain = math.ceil(n_trainset/filePerBatch)
    

    for iterout in range(totalBatchToTrain):
        # Add timer
        startT = time.time()

        # Change current batch
        trainer.Save(p_name)
        print('Batch: ', iterout)
        files_for_batch = TrainFiles[iterout*filePerBatch:(iterout + 1)*filePerBatch]
        print(files_for_batch)
        # trainer.Load('outputs/neuralnet_trained.p')
        try:
            # Run few times on same set of files
            for iterin in range(iterationPerBatch):
                print('ITERATION IN', iterin)        
                for fn in files_for_batch:
                    trainFileName = fn.replace('.ds.bz2', '.p2')
                    sentenceObj = loaded_SKT[trainFileName]
                    dcsObj = loaded_DCS[trainFileName]
                    if trainingStatus[sentenceObj.sent_id]:
                        continue
                    # trainer.Save('outputs/saved_trainer.p')
                    try:
                        trainer.Train(sentenceObj, dcsObj, _debug)
                    except (IndexError, KeyError) as e:
                        print('\x1b[31mFailed: {} \x1b[0m'.format(sentenceObj.sent_id))
                sys.stdout.flush() # Flush IO buffer 
            finishT = time.time()
            print('Avg. time taken by 1 file(1 iteration): {:.3f}'.format((finishT - startT)/(iterationPerBatch*filePerBatch)))
        except KeyboardInterrupt:
            print('Training paused')
            trainer.Save(p_name)
            yield 'Hi'
    trainer.Save(p_name)
    
    sys.stdout.flush() # Flush IO buffer 
                
def test(loaded_SKT, loaded_DCS, n_testSet = -1, _testFiles = None, n_checkpt = 100):
    total_lemma = 0;
    correct_lemma = 0;

    total_word = 0;
    total_output_nodes = 0
    correct_word = 0;
    file_counter = 0
    if _testFiles is None:
        if n_testSet == -1:
            _testFiles = TestFiles
        else:
            _testFiles = TestFiles[0:n_testSet]
    else:
        if n_testSet == -1:
            _testFiles = _testFiles
        else:
            _testFiles = _testFiles[0:n_testSet]
            
    recalls = []
    recalls_of_word = []
    precisions = []
    precisions_of_words = []
    for fn in _testFiles:
        if file_counter % n_checkpt == 0:
            print(file_counter,' Checkpoint... ')
            sys.stdout.flush() # Flush IO buffer 
        
        file_counter += 1
        
        testFileName = fn.replace('.ds.bz2', '.p2')
        sentenceObj = loaded_SKT[testFileName]
        dcsObj = loaded_DCS[testFileName]
        
        try:
            (word_match, lemma_match, n_dcsWords, n_output_nodes) = trainer.Test(sentenceObj, dcsObj)
            
            recalls.append(lemma_match/n_dcsWords)
            recalls_of_word.append(word_match/n_dcsWords)
            
            precisions.append(lemma_match/n_output_nodes)
            precisions_of_words.append(word_match/n_output_nodes)
            
            total_lemma += n_dcsWords
            total_word += n_dcsWords
            
            total_output_nodes += n_output_nodes            
            
            correct_lemma += lemma_match
            correct_word += word_match
        except (IndexError, KeyError) as e:
            print('Failed!')        

    print('Avg. Micro Recall of Lemmas: {}'.format(np.mean(np.array(recalls))))
    print('Avg. Micro Recall of Words: {}'.format(np.mean(np.array(recalls_of_word))))
    print('Avg. Micro Precision of Lemmas: {}'.format(np.mean(np.array(precisions))))
    print('Avg. Micro Precision of Words: {}'.format(np.mean(np.array(precisions_of_words))))
    
    return (recalls, recalls_of_word, precisions, precisions_of_words)

# %%
# NOW-OLD FUNCTION
# def GetLoss(_mst_adj_graph, _mask_de_correct_edges, _negLogLikelies):
#     _negLogLikelies = _negLogLikelies.copy()
#     _negLogLikelies[~_mst_adj_graph] = 0
#     _negLogLikelies[~_mask_de_correct_edges] *= -1 # BAKA!!! Check before you try to fix this again
#     return np.sum(_negLogLikelies)    

# NEW FUNCTION
def GetLoss(_mst_adj_graph, _mask_de_correct_edges, _WScalarMat):
    _WScalarMat = _WScalarMat.copy()
    _WScalarMat[_mst_adj_graph&(~_mask_de_correct_edges)] *= -1 # BAKA!!! Check before you try to fix this again
    _WScalarMat[~_mst_adj_graph] = 0
    return np.sum(_WScalarMat)

# %%
"""
################################################################################################
##############################  GET A FILENAME TO SAVE WEIGHTS  ################################
################################################################################################
"""
import time
st = str(int((time.time() * 1e6) % 1e13))
log_name = 'logs/train_nnet_t{}.out'.format(st)
p_name = 'outputs/train_nnet_t{}.p'.format(st)
print('nEURAL nET wILL bE sAVED hERE: ', p_name)
# Out:
# nEURAL nET wILL bE sAVED hERE:  outputs/train_nnet_t968556199949.p

# %%
class Trainer:
    def __init__(self, modelFile = None):
        if modelFile is None:
            self.hidden_layer_size = 800
            self._edge_vector_dim = 1000
            # self._edge_vector_dim = WD._edge_vector_dim
            # self._full_cnglist = list(WD.mat_cngCount_1D)
            
            self.neuralnet = NN(self._edge_vector_dim, self.hidden_layer_size, outer_relu=True)
            self.history = defaultdict(lambda: list())
        else:
            loader = pickle.load(open(filename, 'rb'))
            
            self.neuralnet.hidden_layer_size = loader['n']
            self.neuralnet._edge_vector_dim = loader['d']

            self.neuralnet = NN(self._edge_vector_dim, self.hidden_layer_size, outer_relu=True)

            self.neuralnet.U = loader['U']
            self.neuralnet.W = loader['W']
            self.neuralnet.B1 = loader['B1']
            self.neuralnet.B2 = loader['B2']
            
            self.history = defaultdict(lambda: list())
        
        # SET LEARNING RATES
        self.neuralnet.etaW = 3e-5
        self.neuralnet.etaB1 = 1e-5
        
        self.neuralnet.etaU = 1e-5
        self.neuralnet.etaB2 = 1e-5
            
    def Reset(self):
        self.neuralnet = NN(self._edge_vector_dim, self.hidden_layer_size)
        self.history = defaultdict(lambda: list())
        
    def Save(self, filename):
        print('Weights Saved: ', p_name)
        pickle.dump({
                'U': self.neuralnet.U,
                'W': self.neuralnet.W,
                'n': self.neuralnet.n,
                'd': self.neuralnet.d,
                'B1': self.neuralnet.B1,
                'B2': self.neuralnet.B2
            }, open(p_name, 'wb'))
        return
        
    
    def Load(self, filename):
        loader = pickle.load(open(filename, 'rb'))
        self.neuralnet.U = loader['U']
        self.neuralnet.W = loader['W']
        self.neuralnet.B1 = loader['B1']
        self.neuralnet.B2 = loader['B2']
        self.neuralnet.hidden_layer_size = loader['n']
        self.neuralnet._edge_vector_dim = loader['d']
        
    def Test(self, sentenceObj, dcsObj, dsbz2_name):
        neuralnet = self.neuralnet
        minScore = np.inf
        minMst = None
        
        # dsbz2_name = sentenceObj.sent_id + '.ds.bz2'
        (nodelist_correct, conflicts_Dict_correct, featVMat_correct, nodelist_to_correct_mapping,\
            nodelist, conflicts_Dict, featVMat) = open_dsbz2(dsbz2_name)
        
        if not self.neuralnet.outer_relu:
            (WScalarMat, SigmoidGateOutput) = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        else:
            WScalarMat = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        
        # print('NeuralNet Time: ', time.time() - startT)
        # startT = time.time()
        
        # Get all MST
        for source in range(len(nodelist)):
            (mst_nodes, mst_adj_graph, _) = MST(nodelist, WScalarMat, conflicts_Dict, source)
            # print('.', end = '')
            score = GetMSTWeight(mst_adj_graph, WScalarMat)
            if(score < minScore):
                minScore = score
                minMst = mst_nodes
        dcsLemmas = [[rom_slp(l) for l in arr]for arr in dcsObj.lemmas]
        word_match = 0
        lemma_match = 0
        n_output_nodes = 0
        for chunk_id, wdSplit in minMst.items():
            for wd in wdSplit:
                n_output_nodes += 1
                # Match lemma
                search_result = [i for i, j in enumerate(dcsLemmas[chunk_id]) if j == wd.lemma]
                if len(search_result) > 0:
                    lemma_match += 1
                # Match CNG
                for i in search_result:
                    if(dcsObj.cng[chunk_id][i] == str(wd.cng)):
                        word_match += 1
                        # print(wd.lemma, wd.cng)
                        break
        dcsLemmas = [l for arr in dcsObj.lemmas for l in arr]
        
        # print('All MST Time: ', time.time() - startT)
        # print('Node Count: ', len(nodelist))
#         print('\nFull Match: {}, Partial Match: {}, OutOf {}, NodeCount: {}, '.\
#               format(word_match, lemma_match, len(dcsLemmas), len(nodelist)))
        return (word_match, lemma_match, len(dcsLemmas), n_output_nodes)
    
    def Train(self, sentenceObj, dcsObj, _debug = True):
        # Hyperparameter for hinge loss: m
        m_hinge_param = 14
        
        dsbz2_name = sentenceObj.sent_id + '.ds.bz2'
        (nodelist_correct, conflicts_Dict_correct, featVMat_correct, nodelist_to_correct_mapping,\
            nodelist, conflicts_Dict, featVMat) = open_dsbz2('../NewData/skt_dcs_DS.bz2_10K/' + dsbz2_name)
        
        # Train for large graphs separately
#         if len(nodelist) < 40:
#             return
        
        """ FORM MAXIMUM(ENERGY) SPANNING TREE OF THE GOLDEN GRAPH : WORST GOLD STRUCTURE """
        WScalarMat_correct = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat_correct, nodelist_correct,\
                                                                      conflicts_Dict_correct, self.neuralnet)
        source = 0
        """ Find the max spanning tree : negative Weight matrix passed """
        (max_st_gold_ndict, max_st_adj_gold_small, _) =\
            MST(nodelist_correct, -WScalarMat_correct, conflicts_Dict_correct, source)
#         (max_st_gold_ndict, max_st_adj_gold_small, _) =\
#             RandomST_GoldOnly(nodelist_correct, -WScalarMat_correct, conflicts_Dict_correct, source)
        energy_gold_max_ST = np.sum(WScalarMat_correct[max_st_adj_gold_small])
        
        """ Convert correct spanning tree graph adj matrix to full marix dimensions """
        """ Create full-size adjacency matrix for correct_mst_small """
        nodelen = len(nodelist)
        max_st_adj_gold = np.ndarray((nodelen, nodelen), np.bool)*False # T_STAR
        for i in range(max_st_adj_gold_small.shape[0]):
            for j in range(max_st_adj_gold_small.shape[1]):
                max_st_adj_gold[nodelist_to_correct_mapping[i], nodelist_to_correct_mapping[j]] =\
                    max_st_adj_gold_small[i, j]
        
        """ Delta(Margin) Function : MASK FOR WHICH NODES IN NODELIST BELONG TO DCS """
        gold_nodes_mask = np.array([False]*len(nodelist))
        gold_nodes_mask[list(nodelist_to_correct_mapping.values())] = True
        margin_f = lambda nodes_mask: np.sum(nodes_mask&(~gold_nodes_mask))
        
        """ FOR ALL POSSIBLE MST FROM THE COMPLETE GRAPH """
        WScalarMat = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, self.neuralnet)

        """ For each node - Find MST with that source"""
        min_STx = None # Min Energy spanning tree with worst margin with gold_STx
        min_marginalized_energy = np.inf
        
        # Generate random set of nodes from which mSTs are to be considered
        n_nodes = len(nodelist)
        selection_prob = 0.5
        select_flag = np.random.rand(n_nodes) < selection_prob
        # Fix if all zeros
        if np.sum(select_flag) == 0:
            select_flag[np.random.randint(n_nodes)] = 1
        
        for source in range(len(nodelist)):
            (mst_nodes, mst_adj_graph, mst_nodes_bool) = MST(nodelist, WScalarMat, conflicts_Dict, source) # T_X
            # print('.', end = '')
           
            marginalized_en = np.sum(WScalarMat[mst_adj_graph]) - margin_f(mst_nodes_bool)
            # Minimum marginalized spanning tree : Randomization applied
            # if marginalized_en < min_marginalized_energy and select_flag[source]:
            if marginalized_en < min_marginalized_energy:
                min_marginalized_energy = marginalized_en
                min_STx = mst_adj_graph
            # Energy diff should all be negative
            if _debug:
                print('Source: [{}], Node_Diff:{}, Max_Gold_En: {:.3f}, Energy: {:.3f}'.\
                      format(source, np.sum((~gold_nodes_mask)&mst_nodes_bool), energy_gold_max_ST,  np.sum(WScalarMat[mst_adj_graph])))

        """ Gradient Descent """
        # FOR MOST OFFENdING Y
        doBpp = False
        
        Total_Loss = energy_gold_max_ST - min_marginalized_energy
        if Total_Loss > 0:
            dLdOut = np.zeros_like(WScalarMat)
            dLdOut[max_st_adj_gold&(~min_STx)] = 1
            dLdOut[(~max_st_adj_gold)&min_STx] = -1
            if _debug:
                print('{}. '.format(sentenceObj.sent_id), end = '')
            self.neuralnet.Back_Prop(dLdOut, len(nodelist), featVMat, _debug)
        else:
            trainingStatus[sentenceObj.sent_id] = True
        if _debug:
            print("\nFileKey: %s, Loss: %6.3f" % (sentenceObj.sent_id, Total_Loss))

# %%
# trainer.neuralnet.U

# %%
trainer = None
def InitModule(_matDB):
    global trainer
#     global WD, trainer
#     WD.word_definite_extInit(_matDB)
    trainer = Trainer()
# InitModule(matDB)
InitModule(None)
trainingStatus = defaultdict(lambda: bool(False))
# trainer.Load('outputs/train_nnet_t526539685574.p')

# %%
"""
################################################################################################
################################################################################################
################################################################################################
"""
# if __name__ == '__main__':
# loaded_SKT = pickle.load(open('../Simultaneous_CompatSKT_10K.p', 'rb'))
# loaded_DCS = pickle.load(open('../Simultaneous_DCS_10K.p', 'rb'))
# main(loaded_SKT, loaded_DCS)
np.set_printoptions(suppress=False)

fn = TrainFiles[0].replace('.ds.bz2', '.p2')
for _ in range(5):
    trainer.Train(loaded_SKT[fn], loaded_DCS[fn], _debug = True)

# # fn = TestFiles[1].replace('.ds.bz2', '.p2')
# trainer.Test(loaded_SKT[fn], loaded_DCS[fn])
# print ("Not Implemented")

# %%
train = train_generator(loaded_SKT, loaded_DCS, n_trainset = -1, filePerBatch = 10, iterationPerBatch = 5, _debug=False)

# %%
# Complete Training
# tips: try increasing iterations per batch
trainingStatus = defaultdict(lambda: bool(False)) # Reset it after 3 epochs of full-training set
train.__next__()
playBeep()
# Out:
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  18
# ['366121.ds.bz2', '174983.ds.bz2', '293407.ds.bz2', '133928.ds.bz2', '355245.ds.bz2', '307038.ds.bz2', '26318.ds.bz2', '34180.ds.bz2', '347150.ds.bz2', '260971.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.453
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  19
# ['18527.ds.bz2', '133943.ds.bz2', '176286.ds.bz2', '11345.ds.bz2', '152261.ds.bz2', '31956.ds.bz2', '328656.ds.bz2', '34794.ds.bz2', '308450.ds.bz2', '39906.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.956
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  20
# ['39912.ds.bz2', '20235.ds.bz2', '382547.ds.bz2', '99489.ds.bz2', '20310.ds.bz2', '161250.ds.bz2', '17254.ds.bz2', '82788.ds.bz2', '273840.ds.bz2', '4895.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.531
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  21
# ['389766.ds.bz2', '125234.ds.bz2', '279037.ds.bz2', '68480.ds.bz2', '115672.ds.bz2', '367744.ds.bz2', '209688.ds.bz2', '142505.ds.bz2', '33961.ds.bz2', '236532.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.108
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  22
# ['367270.ds.bz2', '40558.ds.bz2', '106492.ds.bz2', '32062.ds.bz2', '421491.ds.bz2', '24063.ds.bz2', '368040.ds.bz2', '214288.ds.bz2', '36169.ds.bz2', '41118.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.320
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  23
# ['398472.ds.bz2', '126302.ds.bz2', '418252.ds.bz2', '14490.ds.bz2', '371651.ds.bz2', '415508.ds.bz2', '253953.ds.bz2', '84305.ds.bz2', '246157.ds.bz2', '121275.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.691
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  24
# ['41543.ds.bz2', '131913.ds.bz2', '286941.ds.bz2', '814.ds.bz2', '358575.ds.bz2', '70178.ds.bz2', '395135.ds.bz2', '66244.ds.bz2', '277747.ds.bz2', '205081.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.204
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  25
# ['392821.ds.bz2', '340044.ds.bz2', '283770.ds.bz2', '8256.ds.bz2', '301584.ds.bz2', '345824.ds.bz2', '29590.ds.bz2', '292126.ds.bz2', '119551.ds.bz2', '19845.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.884
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  26
# ['30080.ds.bz2', '350517.ds.bz2', '38860.ds.bz2', '36998.ds.bz2', '16875.ds.bz2', '100514.ds.bz2', '379827.ds.bz2', '260894.ds.bz2', '46062.ds.bz2', '423443.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.149
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  27
# ['99027.ds.bz2', '363181.ds.bz2', '43192.ds.bz2', '90037.ds.bz2', '427624.ds.bz2', '87605.ds.bz2', '39908.ds.bz2', '167263.ds.bz2', '34362.ds.bz2', '377279.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.744
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  28
# ['33894.ds.bz2', '298983.ds.bz2', '267202.ds.bz2', '33162.ds.bz2', '94445.ds.bz2', '159320.ds.bz2', '34979.ds.bz2', '35798.ds.bz2', '181258.ds.bz2', '225436.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.924
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  29
# ['418406.ds.bz2', '248186.ds.bz2', '25264.ds.bz2', '29113.ds.bz2', '138136.ds.bz2', '9709.ds.bz2', '295888.ds.bz2', '287273.ds.bz2', '274787.ds.bz2', '24010.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.500
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  30
# ['159931.ds.bz2', '334555.ds.bz2', '20000.ds.bz2', '327856.ds.bz2', '90116.ds.bz2', '2723.ds.bz2', '11095.ds.bz2', '139031.ds.bz2', '193322.ds.bz2', '4366.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.147
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  31
# ['357487.ds.bz2', '347229.ds.bz2', '160936.ds.bz2', '245078.ds.bz2', '18155.ds.bz2', '132845.ds.bz2', '231919.ds.bz2', '328780.ds.bz2', '310637.ds.bz2', '92853.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.875
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  32
# ['30623.ds.bz2', '19532.ds.bz2', '45117.ds.bz2', '79150.ds.bz2', '320114.ds.bz2', '163968.ds.bz2', '313281.ds.bz2', '273412.ds.bz2', '45463.ds.bz2', '4058.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.483
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  33
# ['224242.ds.bz2', '38873.ds.bz2', '439900.ds.bz2', '432920.ds.bz2', '221957.ds.bz2', '367762.ds.bz2', '293184.ds.bz2', '440218.ds.bz2', '406731.ds.bz2', '34503.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.178
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  34
# ['40319.ds.bz2', '240927.ds.bz2', '168717.ds.bz2', '15649.ds.bz2', '438775.ds.bz2', '423341.ds.bz2', '136540.ds.bz2', '407259.ds.bz2', '272287.ds.bz2', '26954.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.905
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  35
# ['63111.ds.bz2', '117775.ds.bz2', '153688.ds.bz2', '304798.ds.bz2', '332745.ds.bz2', '5215.ds.bz2', '8826.ds.bz2', '173068.ds.bz2', '338320.ds.bz2', '427507.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.000
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  36
# ['29778.ds.bz2', '10529.ds.bz2', '15989.ds.bz2', '12051.ds.bz2', '422413.ds.bz2', '270888.ds.bz2', '183174.ds.bz2', '402008.ds.bz2', '314513.ds.bz2', '32067.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.689
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  37
# ['337024.ds.bz2', '30922.ds.bz2', '416409.ds.bz2', '117411.ds.bz2', '153686.ds.bz2', '4896.ds.bz2', '169852.ds.bz2', '343476.ds.bz2', '299588.ds.bz2', '8310.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.531
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  38
# ['447.ds.bz2', '35148.ds.bz2', '59300.ds.bz2', '25521.ds.bz2', '8100.ds.bz2', '32715.ds.bz2', '4980.ds.bz2', '43515.ds.bz2', '80056.ds.bz2', '18010.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.329
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  39
# ['333222.ds.bz2', '208536.ds.bz2', '347337.ds.bz2', '165275.ds.bz2', '60997.ds.bz2', '200665.ds.bz2', '294115.ds.bz2', '206170.ds.bz2', '209214.ds.bz2', '337271.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.883
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  40
# ['11189.ds.bz2', '60770.ds.bz2', '4166.ds.bz2', '18354.ds.bz2', '128468.ds.bz2', '72847.ds.bz2', '441056.ds.bz2', '72192.ds.bz2', '19182.ds.bz2', '41533.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.853
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  41
# ['8238.ds.bz2', '421820.ds.bz2', '374525.ds.bz2', '386312.ds.bz2', '3724.ds.bz2', '17863.ds.bz2', '175625.ds.bz2', '411479.ds.bz2', '158623.ds.bz2', '45556.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.786
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  42
# ['24995.ds.bz2', '18104.ds.bz2', '272849.ds.bz2', '322748.ds.bz2', '323571.ds.bz2', '364870.ds.bz2', '182293.ds.bz2', '62011.ds.bz2', '45414.ds.bz2', '34228.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.004
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  43
# ['156934.ds.bz2', '293964.ds.bz2', '29364.ds.bz2', '41968.ds.bz2', '39478.ds.bz2', '235850.ds.bz2', '24363.ds.bz2', '15096.ds.bz2', '334336.ds.bz2', '189564.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.269
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  44
# ['238076.ds.bz2', '41012.ds.bz2', '32169.ds.bz2', '255064.ds.bz2', '28358.ds.bz2', '149668.ds.bz2', '1398.ds.bz2', '11180.ds.bz2', '262741.ds.bz2', '430409.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.586
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  45
# ['281525.ds.bz2', '289519.ds.bz2', '6266.ds.bz2', '408542.ds.bz2', '156949.ds.bz2', '24856.ds.bz2', '11251.ds.bz2', '207212.ds.bz2', '176351.ds.bz2', '389746.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.914
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  46
# ['367387.ds.bz2', '27444.ds.bz2', '8144.ds.bz2', '143280.ds.bz2', '433682.ds.bz2', '33688.ds.bz2', '273612.ds.bz2', '66268.ds.bz2', '252313.ds.bz2', '439444.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.885
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  47
# ['14674.ds.bz2', '43250.ds.bz2', '358399.ds.bz2', '384597.ds.bz2', '165254.ds.bz2', '50420.ds.bz2', '418469.ds.bz2', '137542.ds.bz2', '2122.ds.bz2', '355001.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.533
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  48
# ['149405.ds.bz2', '62904.ds.bz2', '90492.ds.bz2', '214118.ds.bz2', '321556.ds.bz2', '2681.ds.bz2', '213062.ds.bz2', '339226.ds.bz2', '33092.ds.bz2', '395058.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.566
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  49
# ['28433.ds.bz2', '44651.ds.bz2', '45683.ds.bz2', '367.ds.bz2', '429999.ds.bz2', '286730.ds.bz2', '277422.ds.bz2', '159907.ds.bz2', '262344.ds.bz2', '32827.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.938
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  50
# ['345011.ds.bz2', '421760.ds.bz2', '368092.ds.bz2', '432870.ds.bz2', '23339.ds.bz2', '176292.ds.bz2', '277507.ds.bz2', '19650.ds.bz2', '375024.ds.bz2', '421654.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.166
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  51
# ['13822.ds.bz2', '73849.ds.bz2', '137270.ds.bz2', '298990.ds.bz2', '43720.ds.bz2', '151220.ds.bz2', '31866.ds.bz2', '233469.ds.bz2', '11374.ds.bz2', '256778.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.476
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  52
# ['411828.ds.bz2', '339786.ds.bz2', '18736.ds.bz2', '179089.ds.bz2', '432014.ds.bz2', '215833.ds.bz2', '24892.ds.bz2', '271780.ds.bz2', '32497.ds.bz2', '109481.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.232
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  53
# ['246935.ds.bz2', '320889.ds.bz2', '7861.ds.bz2', '170312.ds.bz2', '70361.ds.bz2', '435641.ds.bz2', '351695.ds.bz2', '143562.ds.bz2', '43088.ds.bz2', '438014.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.027
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  54
# ['413358.ds.bz2', '277546.ds.bz2', '25812.ds.bz2', '316575.ds.bz2', '137911.ds.bz2', '354173.ds.bz2', '304575.ds.bz2', '61559.ds.bz2', '323862.ds.bz2', '34352.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.418
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  55
# ['296530.ds.bz2', '8785.ds.bz2', '287553.ds.bz2', '69160.ds.bz2', '2620.ds.bz2', '370901.ds.bz2', '41566.ds.bz2', '198617.ds.bz2', '354205.ds.bz2', '388713.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.819
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  56
# ['9701.ds.bz2', '83711.ds.bz2', '231391.ds.bz2', '249665.ds.bz2', '23222.ds.bz2', '389979.ds.bz2', '356590.ds.bz2', '112986.ds.bz2', '66617.ds.bz2', '106117.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.689
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  57
# ['396180.ds.bz2', '431466.ds.bz2', '115197.ds.bz2', '127807.ds.bz2', '2331.ds.bz2', '125174.ds.bz2', '37617.ds.bz2', '262769.ds.bz2', '379060.ds.bz2', '138546.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.454
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  58
# ['169303.ds.bz2', '197585.ds.bz2', '54388.ds.bz2', '361828.ds.bz2', '114852.ds.bz2', '20645.ds.bz2', '95973.ds.bz2', '441265.ds.bz2', '96434.ds.bz2', '19257.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.039
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  59
# ['31931.ds.bz2', '371786.ds.bz2', '40697.ds.bz2', '326681.ds.bz2', '330353.ds.bz2', '417297.ds.bz2', '290365.ds.bz2', '22782.ds.bz2', '25169.ds.bz2', '556.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.150
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  60
# ['229154.ds.bz2', '32347.ds.bz2', '31079.ds.bz2', '264797.ds.bz2', '285449.ds.bz2', '20094.ds.bz2', '335663.ds.bz2', '80884.ds.bz2', '7749.ds.bz2', '130050.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.121
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  61
# ['110874.ds.bz2', '123176.ds.bz2', '27407.ds.bz2', '277140.ds.bz2', '103056.ds.bz2', '166589.ds.bz2', '229232.ds.bz2', '216458.ds.bz2', '437569.ds.bz2', '133906.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.870
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  62
# ['30758.ds.bz2', '6133.ds.bz2', '262351.ds.bz2', '55890.ds.bz2', '216874.ds.bz2', '81963.ds.bz2', '24043.ds.bz2', '28886.ds.bz2', '232922.ds.bz2', '30719.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.801
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  63
# ['437394.ds.bz2', '272057.ds.bz2', '37994.ds.bz2', '36450.ds.bz2', '37294.ds.bz2', '1380.ds.bz2', '40019.ds.bz2', '102723.ds.bz2', '435751.ds.bz2', '3608.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.347
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  64
# ['1176.ds.bz2', '1485.ds.bz2', '223619.ds.bz2', '11568.ds.bz2', '420511.ds.bz2', '27104.ds.bz2', '248887.ds.bz2', '56911.ds.bz2', '404447.ds.bz2', '36121.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.945
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  65
# ['9668.ds.bz2', '407464.ds.bz2', '587.ds.bz2', '46387.ds.bz2', '88631.ds.bz2', '6903.ds.bz2', '357073.ds.bz2', '17892.ds.bz2', '265637.ds.bz2', '302360.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.930
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  66
# ['17258.ds.bz2', '333186.ds.bz2', '87602.ds.bz2', '155197.ds.bz2', '20753.ds.bz2', '350086.ds.bz2', '343873.ds.bz2', '313388.ds.bz2', '31140.ds.bz2', '20062.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.994
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  67
# ['201182.ds.bz2', '349293.ds.bz2', '261990.ds.bz2', '226301.ds.bz2', '159552.ds.bz2', '233330.ds.bz2', '129896.ds.bz2', '11351.ds.bz2', '76323.ds.bz2', '56180.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.652
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  68
# ['157788.ds.bz2', '28409.ds.bz2', '29798.ds.bz2', '39431.ds.bz2', '371737.ds.bz2', '392725.ds.bz2', '10682.ds.bz2', '272391.ds.bz2', '349121.ds.bz2', '28629.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.726
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  69
# ['425370.ds.bz2', '141141.ds.bz2', '289985.ds.bz2', '42125.ds.bz2', '15014.ds.bz2', '5435.ds.bz2', '280831.ds.bz2', '277666.ds.bz2', '45568.ds.bz2', '328837.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.249
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  70
# ['33749.ds.bz2', '431210.ds.bz2', '311747.ds.bz2', '234453.ds.bz2', '44952.ds.bz2', '180850.ds.bz2', '46246.ds.bz2', '24924.ds.bz2', '33394.ds.bz2', '8989.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.265
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  71
# ['37189.ds.bz2', '200066.ds.bz2', '416788.ds.bz2', '45650.ds.bz2', '295379.ds.bz2', '352100.ds.bz2', '38017.ds.bz2', '359602.ds.bz2', '143877.ds.bz2', '428817.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 3.345
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  72
# ['422144.ds.bz2', '14977.ds.bz2', '126880.ds.bz2', '198514.ds.bz2', '12445.ds.bz2', '325400.ds.bz2', '45245.ds.bz2', '165243.ds.bz2', '83597.ds.bz2', '299070.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.588
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  73
# ['833.ds.bz2', '7294.ds.bz2', '39114.ds.bz2', '11250.ds.bz2', '132266.ds.bz2', '223019.ds.bz2', '316740.ds.bz2', '40223.ds.bz2', '295761.ds.bz2', '39935.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.511
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  74
# ['71580.ds.bz2', '141417.ds.bz2', '332137.ds.bz2', '28197.ds.bz2', '162522.ds.bz2', '433932.ds.bz2', '80320.ds.bz2', '92199.ds.bz2', '411.ds.bz2', '231298.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.984
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  75
# ['195129.ds.bz2', '4714.ds.bz2', '153661.ds.bz2', '67576.ds.bz2', '13910.ds.bz2', '150176.ds.bz2', '40262.ds.bz2', '304794.ds.bz2', '263412.ds.bz2', '169417.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.790
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  76
# ['356268.ds.bz2', '329140.ds.bz2', '411645.ds.bz2', '326996.ds.bz2', '19533.ds.bz2', '153553.ds.bz2', '40892.ds.bz2', '2220.ds.bz2', '424657.ds.bz2', '309264.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.834
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  77
# ['354135.ds.bz2', '29453.ds.bz2', '15987.ds.bz2', '28640.ds.bz2', '118379.ds.bz2', '283645.ds.bz2', '363967.ds.bz2', '35015.ds.bz2', '44013.ds.bz2', '421662.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.495
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  78
# ['395093.ds.bz2', '34454.ds.bz2', '108076.ds.bz2', '422194.ds.bz2', '36574.ds.bz2', '248396.ds.bz2', '4463.ds.bz2', '293716.ds.bz2', '17726.ds.bz2', '30344.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.808
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  79
# ['409070.ds.bz2', '219284.ds.bz2', '153846.ds.bz2', '42963.ds.bz2', '366682.ds.bz2', '186294.ds.bz2', '164953.ds.bz2', '11114.ds.bz2', '138804.ds.bz2', '65534.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.756
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  80
# ['325609.ds.bz2', '322356.ds.bz2', '41659.ds.bz2', '130631.ds.bz2', '428908.ds.bz2', '3742.ds.bz2', '124604.ds.bz2', '344916.ds.bz2', '8241.ds.bz2', '123612.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.217
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  81
# ['27213.ds.bz2', '143353.ds.bz2', '45932.ds.bz2', '95759.ds.bz2', '15609.ds.bz2', '433854.ds.bz2', '181223.ds.bz2', '279075.ds.bz2', '351575.ds.bz2', '82454.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.991
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  82
# ['11358.ds.bz2', '26080.ds.bz2', '43325.ds.bz2', '324754.ds.bz2', '420843.ds.bz2', '434465.ds.bz2', '365627.ds.bz2', '369289.ds.bz2', '325644.ds.bz2', '1843.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.329
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  83
# ['318650.ds.bz2', '417346.ds.bz2', '438459.ds.bz2', '98076.ds.bz2', '343235.ds.bz2', '332917.ds.bz2', '137649.ds.bz2', '212325.ds.bz2', '190340.ds.bz2', '344280.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.820
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  84
# ['295737.ds.bz2', '266346.ds.bz2', '210838.ds.bz2', '160481.ds.bz2', '66531.ds.bz2', '268409.ds.bz2', '140835.ds.bz2', '117826.ds.bz2', '39698.ds.bz2', '7869.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.599
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  85
# ['171959.ds.bz2', '27170.ds.bz2', '136469.ds.bz2', '230680.ds.bz2', '237316.ds.bz2', '375244.ds.bz2', '253575.ds.bz2', '273173.ds.bz2', '45805.ds.bz2', '288632.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.815
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  86
# ['59144.ds.bz2', '37115.ds.bz2', '435315.ds.bz2', '20526.ds.bz2', '291963.ds.bz2', '317026.ds.bz2', '437631.ds.bz2', '141846.ds.bz2', '37131.ds.bz2', '391668.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.214
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  87
# ['8315.ds.bz2', '191461.ds.bz2', '105451.ds.bz2', '1991.ds.bz2', '352263.ds.bz2', '312016.ds.bz2', '403816.ds.bz2', '236582.ds.bz2', '137853.ds.bz2', '292142.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.581
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  88
# ['24814.ds.bz2', '369398.ds.bz2', '338770.ds.bz2', '377401.ds.bz2', '316413.ds.bz2', '45914.ds.bz2', '70802.ds.bz2', '103785.ds.bz2', '199431.ds.bz2', '131617.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.344
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  89
# ['76036.ds.bz2', '440655.ds.bz2', '247517.ds.bz2', '81998.ds.bz2', '151321.ds.bz2', '25739.ds.bz2', '24860.ds.bz2', '131250.ds.bz2', '313811.ds.bz2', '344947.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.580
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  90
# ['79284.ds.bz2', '11231.ds.bz2', '311331.ds.bz2', '178363.ds.bz2', '384913.ds.bz2', '74150.ds.bz2', '64613.ds.bz2', '81792.ds.bz2', '30020.ds.bz2', '5400.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.585
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  91
# ['236400.ds.bz2', '208044.ds.bz2', '385481.ds.bz2', '9174.ds.bz2', '392592.ds.bz2', '166960.ds.bz2', '30146.ds.bz2', '17182.ds.bz2', '262388.ds.bz2', '200234.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.103
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  92
# ['240010.ds.bz2', '112297.ds.bz2', '40657.ds.bz2', '214669.ds.bz2', '44307.ds.bz2', '147837.ds.bz2', '22315.ds.bz2', '11577.ds.bz2', '93971.ds.bz2', '32434.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.585
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  93
# ['6551.ds.bz2', '440755.ds.bz2', '434417.ds.bz2', '181997.ds.bz2', '36512.ds.bz2', '8293.ds.bz2', '34599.ds.bz2', '82258.ds.bz2', '20568.ds.bz2', '35128.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.102
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  94
# ['393114.ds.bz2', '104626.ds.bz2', '291388.ds.bz2', '214405.ds.bz2', '95126.ds.bz2', '315306.ds.bz2', '94175.ds.bz2', '95730.ds.bz2', '341896.ds.bz2', '380577.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.118
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  95
# ['413962.ds.bz2', '323023.ds.bz2', '339942.ds.bz2', '265337.ds.bz2', '183860.ds.bz2', '9888.ds.bz2', '29106.ds.bz2', '348342.ds.bz2', '4918.ds.bz2', '408301.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.245
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  96
# ['142917.ds.bz2', '287070.ds.bz2', '163852.ds.bz2', '330967.ds.bz2', '337056.ds.bz2', '264968.ds.bz2', '7295.ds.bz2', '40006.ds.bz2', '25249.ds.bz2', '41499.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.005
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  97
# ['430626.ds.bz2', '434656.ds.bz2', '29460.ds.bz2', '317639.ds.bz2', '32262.ds.bz2', '45255.ds.bz2', '26105.ds.bz2', '51084.ds.bz2', '38850.ds.bz2', '180544.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.613
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  98
# ['324801.ds.bz2', '178720.ds.bz2', '402604.ds.bz2', '298237.ds.bz2', '2630.ds.bz2', '31029.ds.bz2', '24045.ds.bz2', '44485.ds.bz2', '436644.ds.bz2', '7275.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 7.410
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  99
# ['27663.ds.bz2', '27062.ds.bz2', '385488.ds.bz2', '304044.ds.bz2', '8986.ds.bz2', '194563.ds.bz2', '2993.ds.bz2', '254119.ds.bz2', '30258.ds.bz2', '273571.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.586
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  100
# ['398386.ds.bz2', '124562.ds.bz2', '43134.ds.bz2', '159656.ds.bz2', '362409.ds.bz2', '82952.ds.bz2', '266983.ds.bz2', '156411.ds.bz2', '17491.ds.bz2', '39065.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.020
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  101
# ['234494.ds.bz2', '37550.ds.bz2', '27422.ds.bz2', '31631.ds.bz2', '21288.ds.bz2', '185877.ds.bz2', '232282.ds.bz2', '227228.ds.bz2', '369300.ds.bz2', '21174.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.777
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  102
# ['43574.ds.bz2', '12420.ds.bz2', '334516.ds.bz2', '46144.ds.bz2', '249795.ds.bz2', '16131.ds.bz2', '368093.ds.bz2', '137350.ds.bz2', '16106.ds.bz2', '349368.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.406
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  103
# ['6453.ds.bz2', '123254.ds.bz2', '427907.ds.bz2', '431319.ds.bz2', '22661.ds.bz2', '796.ds.bz2', '373325.ds.bz2', '41653.ds.bz2', '212017.ds.bz2', '1161.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.665
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  104
# ['5513.ds.bz2', '9833.ds.bz2', '5493.ds.bz2', '386323.ds.bz2', '243670.ds.bz2', '22700.ds.bz2', '11704.ds.bz2', '36770.ds.bz2', '43146.ds.bz2', '25157.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.730
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  105
# ['138286.ds.bz2', '278958.ds.bz2', '280310.ds.bz2', '429043.ds.bz2', '326123.ds.bz2', '17285.ds.bz2', '3367.ds.bz2', '27224.ds.bz2', '216967.ds.bz2', '8985.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.800
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  106
# ['40093.ds.bz2', '139486.ds.bz2', '438425.ds.bz2', '280903.ds.bz2', '379371.ds.bz2', '5810.ds.bz2', '259543.ds.bz2', '216393.ds.bz2', '156136.ds.bz2', '59065.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.849
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  107
# ['140148.ds.bz2', '317307.ds.bz2', '93528.ds.bz2', '201246.ds.bz2', '309673.ds.bz2', '383022.ds.bz2', '228710.ds.bz2', '231954.ds.bz2', '39459.ds.bz2', '125691.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.556
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  108
# ['15619.ds.bz2', '21150.ds.bz2', '28420.ds.bz2', '324171.ds.bz2', '305176.ds.bz2', '36843.ds.bz2', '30255.ds.bz2', '31818.ds.bz2', '43169.ds.bz2', '154627.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.187
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  109
# ['214659.ds.bz2', '41253.ds.bz2', '10962.ds.bz2', '344068.ds.bz2', '110537.ds.bz2', '354271.ds.bz2', '32750.ds.bz2', '427871.ds.bz2', '245932.ds.bz2', '67449.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.652
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  110
# ['41203.ds.bz2', '86772.ds.bz2', '84229.ds.bz2', '273125.ds.bz2', '368779.ds.bz2', '278804.ds.bz2', '371852.ds.bz2', '17797.ds.bz2', '22517.ds.bz2', '14680.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.775
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  111
# ['120199.ds.bz2', '186023.ds.bz2', '166257.ds.bz2', '140147.ds.bz2', '117299.ds.bz2', '31067.ds.bz2', '260958.ds.bz2', '418275.ds.bz2', '332633.ds.bz2', '161043.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.828
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  112
# ['440578.ds.bz2', '52245.ds.bz2', '29293.ds.bz2', '238494.ds.bz2', '166990.ds.bz2', '9698.ds.bz2', '8744.ds.bz2', '241808.ds.bz2', '5449.ds.bz2', '147288.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.760
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  113
# ['11672.ds.bz2', '36383.ds.bz2', '170388.ds.bz2', '13590.ds.bz2', '743.ds.bz2', '20276.ds.bz2', '442273.ds.bz2', '336393.ds.bz2', '19794.ds.bz2', '111473.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.250
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  114
# ['247117.ds.bz2', '20324.ds.bz2', '430548.ds.bz2', '84628.ds.bz2', '30077.ds.bz2', '355146.ds.bz2', '185114.ds.bz2', '387846.ds.bz2', '336268.ds.bz2', '33734.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.533
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  115
# ['40929.ds.bz2', '189852.ds.bz2', '40242.ds.bz2', '29027.ds.bz2', '440604.ds.bz2', '25587.ds.bz2', '7978.ds.bz2', '434658.ds.bz2', '134593.ds.bz2', '128827.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.911
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  116
# ['357092.ds.bz2', '107593.ds.bz2', '135140.ds.bz2', '325731.ds.bz2', '110852.ds.bz2', '255267.ds.bz2', '58122.ds.bz2', '15038.ds.bz2', '142820.ds.bz2', '36945.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.280
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  117
# ['139713.ds.bz2', '340035.ds.bz2', '257271.ds.bz2', '361569.ds.bz2', '40310.ds.bz2', '23224.ds.bz2', '13141.ds.bz2', '195168.ds.bz2', '10791.ds.bz2', '31788.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.053
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  118
# ['337702.ds.bz2', '11032.ds.bz2', '109432.ds.bz2', '19874.ds.bz2', '273550.ds.bz2', '265051.ds.bz2', '385004.ds.bz2', '214157.ds.bz2', '252239.ds.bz2', '26656.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.097
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  119
# ['26645.ds.bz2', '181103.ds.bz2', '435886.ds.bz2', '271747.ds.bz2', '83749.ds.bz2', '60148.ds.bz2', '122251.ds.bz2', '99361.ds.bz2', '257759.ds.bz2', '61873.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.005
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  120
# ['24547.ds.bz2', '333229.ds.bz2', '278510.ds.bz2', '226441.ds.bz2', '11982.ds.bz2', '326951.ds.bz2', '161857.ds.bz2', '107598.ds.bz2', '138285.ds.bz2', '3930.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.666
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  121
# ['284586.ds.bz2', '379992.ds.bz2', '93441.ds.bz2', '207637.ds.bz2', '178014.ds.bz2', '22454.ds.bz2', '18244.ds.bz2', '436255.ds.bz2', '376639.ds.bz2', '82191.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.862
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  122
# ['280702.ds.bz2', '434076.ds.bz2', '357889.ds.bz2', '71798.ds.bz2', '25480.ds.bz2', '53971.ds.bz2', '3537.ds.bz2', '137676.ds.bz2', '7179.ds.bz2', '157677.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.461
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  123
# ['45816.ds.bz2', '153306.ds.bz2', '43642.ds.bz2', '26363.ds.bz2', '26529.ds.bz2', '399994.ds.bz2', '373811.ds.bz2', '4369.ds.bz2', '155967.ds.bz2', '108166.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.715
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  124
# ['7463.ds.bz2', '412032.ds.bz2', '324559.ds.bz2', '110869.ds.bz2', '42250.ds.bz2', '222379.ds.bz2', '134937.ds.bz2', '14827.ds.bz2', '350546.ds.bz2', '42985.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.361
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  125
# ['27450.ds.bz2', '433268.ds.bz2', '8188.ds.bz2', '259369.ds.bz2', '7286.ds.bz2', '1671.ds.bz2', '440418.ds.bz2', '348570.ds.bz2', '274725.ds.bz2', '224659.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.212
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  126
# ['6483.ds.bz2', '42944.ds.bz2', '225357.ds.bz2', '122679.ds.bz2', '5599.ds.bz2', '31641.ds.bz2', '36639.ds.bz2', '232563.ds.bz2', '371555.ds.bz2', '29408.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.420
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  127
# ['35824.ds.bz2', '209434.ds.bz2', '6919.ds.bz2', '9756.ds.bz2', '290271.ds.bz2', '260914.ds.bz2', '41648.ds.bz2', '11631.ds.bz2', '417221.ds.bz2', '93737.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.663
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  128
# ['11101.ds.bz2', '3075.ds.bz2', '349724.ds.bz2', '277212.ds.bz2', '257840.ds.bz2', '318620.ds.bz2', '387911.ds.bz2', '14359.ds.bz2', '158136.ds.bz2', '314171.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.946
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  129
# ['83644.ds.bz2', '270467.ds.bz2', '256951.ds.bz2', '16339.ds.bz2', '153179.ds.bz2', '314699.ds.bz2', '374549.ds.bz2', '293511.ds.bz2', '143213.ds.bz2', '77628.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.639
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  130
# ['20976.ds.bz2', '37561.ds.bz2', '34933.ds.bz2', '419445.ds.bz2', '197401.ds.bz2', '333950.ds.bz2', '195248.ds.bz2', '29300.ds.bz2', '113728.ds.bz2', '57718.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.552
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  131
# ['333711.ds.bz2', '110065.ds.bz2', '21248.ds.bz2', '257115.ds.bz2', '255578.ds.bz2', '408999.ds.bz2', '34445.ds.bz2', '136470.ds.bz2', '231943.ds.bz2', '310877.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.688
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  132
# ['25627.ds.bz2', '323233.ds.bz2', '41503.ds.bz2', '11680.ds.bz2', '265558.ds.bz2', '253157.ds.bz2', '376800.ds.bz2', '259409.ds.bz2', '200626.ds.bz2', '166044.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.792
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  133
# ['35740.ds.bz2', '5819.ds.bz2', '222268.ds.bz2', '311038.ds.bz2', '158198.ds.bz2', '184614.ds.bz2', '7458.ds.bz2', '96819.ds.bz2', '235935.ds.bz2', '8356.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.578
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  134
# ['95218.ds.bz2', '147065.ds.bz2', '106273.ds.bz2', '181256.ds.bz2', '384497.ds.bz2', '6055.ds.bz2', '19672.ds.bz2', '59768.ds.bz2', '259745.ds.bz2', '14875.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.994
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  135
# ['378645.ds.bz2', '63142.ds.bz2', '152845.ds.bz2', '333639.ds.bz2', '127347.ds.bz2', '15151.ds.bz2', '90600.ds.bz2', '287103.ds.bz2', '135826.ds.bz2', '1885.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.241
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  136
# ['33169.ds.bz2', '253551.ds.bz2', '3444.ds.bz2', '436846.ds.bz2', '196731.ds.bz2', '175591.ds.bz2', '32012.ds.bz2', '82423.ds.bz2', '41146.ds.bz2', '240265.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.946
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  137
# ['422290.ds.bz2', '130180.ds.bz2', '289634.ds.bz2', '417994.ds.bz2', '26252.ds.bz2', '44230.ds.bz2', '5797.ds.bz2', '105083.ds.bz2', '287605.ds.bz2', '276593.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.606
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  138
# ['254017.ds.bz2', '42077.ds.bz2', '76340.ds.bz2', '44535.ds.bz2', '1446.ds.bz2', '33905.ds.bz2', '271292.ds.bz2', '167474.ds.bz2', '130581.ds.bz2', '421935.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.744
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  139
# ['6875.ds.bz2', '287717.ds.bz2', '31901.ds.bz2', '29048.ds.bz2', '18320.ds.bz2', '276822.ds.bz2', '278973.ds.bz2', '149667.ds.bz2', '278771.ds.bz2', '427919.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.623
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  140
# ['41311.ds.bz2', '286681.ds.bz2', '413038.ds.bz2', '330006.ds.bz2', '27703.ds.bz2', '353000.ds.bz2', '172890.ds.bz2', '37055.ds.bz2', '312578.ds.bz2', '40144.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.337
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  141
# ['159842.ds.bz2', '1759.ds.bz2', '171646.ds.bz2', '150302.ds.bz2', '191197.ds.bz2', '70983.ds.bz2', '282045.ds.bz2', '76116.ds.bz2', '34609.ds.bz2', '17216.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.653
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  142
# ['428625.ds.bz2', '320270.ds.bz2', '329958.ds.bz2', '41402.ds.bz2', '121047.ds.bz2', '36870.ds.bz2', '435903.ds.bz2', '82508.ds.bz2', '4453.ds.bz2', '247066.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.141
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  143
# ['324852.ds.bz2', '410754.ds.bz2', '369689.ds.bz2', '287189.ds.bz2', '426549.ds.bz2', '42639.ds.bz2', '169633.ds.bz2', '371294.ds.bz2', '5122.ds.bz2', '23189.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.691
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  144
# ['144282.ds.bz2', '159397.ds.bz2', '158836.ds.bz2', '318915.ds.bz2', '345584.ds.bz2', '431058.ds.bz2', '422300.ds.bz2', '267392.ds.bz2', '16150.ds.bz2', '61879.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.497
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  145
# ['328846.ds.bz2', '311492.ds.bz2', '299939.ds.bz2', '279040.ds.bz2', '22688.ds.bz2', '168870.ds.bz2', '280397.ds.bz2', '45326.ds.bz2', '37595.ds.bz2', '64880.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.850
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  146
# ['309273.ds.bz2', '351446.ds.bz2', '329425.ds.bz2', '20869.ds.bz2', '421788.ds.bz2', '278165.ds.bz2', '438686.ds.bz2', '422397.ds.bz2', '337038.ds.bz2', '394939.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.557
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  147
# ['37509.ds.bz2', '277518.ds.bz2', '52987.ds.bz2', '419727.ds.bz2', '439574.ds.bz2', '12441.ds.bz2', '40326.ds.bz2', '6166.ds.bz2', '144272.ds.bz2', '335075.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.485
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  148
# ['237777.ds.bz2', '308653.ds.bz2', '327823.ds.bz2', '6101.ds.bz2', '331183.ds.bz2', '36809.ds.bz2', '40265.ds.bz2', '119553.ds.bz2', '377970.ds.bz2', '301700.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.563
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  149
# ['40296.ds.bz2', '22150.ds.bz2', '148456.ds.bz2', '30374.ds.bz2', '2150.ds.bz2', '53934.ds.bz2', '130415.ds.bz2', '72822.ds.bz2', '45330.ds.bz2', '424563.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.924
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  150
# ['270018.ds.bz2', '11112.ds.bz2', '403805.ds.bz2', '44083.ds.bz2', '345098.ds.bz2', '17947.ds.bz2', '122465.ds.bz2', '116992.ds.bz2', '418324.ds.bz2', '291391.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.753
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  151
# ['322491.ds.bz2', '433315.ds.bz2', '269387.ds.bz2', '275914.ds.bz2', '398747.ds.bz2', '114605.ds.bz2', '6936.ds.bz2', '42115.ds.bz2', '8752.ds.bz2', '25118.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.722
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  152
# ['103452.ds.bz2', '28708.ds.bz2', '101393.ds.bz2', '3937.ds.bz2', '28890.ds.bz2', '163166.ds.bz2', '387964.ds.bz2', '304843.ds.bz2', '153457.ds.bz2', '8251.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.043
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  153
# ['300424.ds.bz2', '413599.ds.bz2', '44941.ds.bz2', '354653.ds.bz2', '37960.ds.bz2', '39716.ds.bz2', '148415.ds.bz2', '280643.ds.bz2', '15148.ds.bz2', '34531.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.901
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  154
# ['5543.ds.bz2', '398973.ds.bz2', '15763.ds.bz2', '335323.ds.bz2', '293969.ds.bz2', '221072.ds.bz2', '16404.ds.bz2', '335980.ds.bz2', '64052.ds.bz2', '404063.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.650
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  155
# ...
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.344
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  361
# ['262298.ds.bz2', '571.ds.bz2', '12516.ds.bz2', '63786.ds.bz2', '43291.ds.bz2', '206744.ds.bz2', '59641.ds.bz2', '9938.ds.bz2', '16320.ds.bz2', '79954.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.491
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  362
# ['308479.ds.bz2', '107020.ds.bz2', '81956.ds.bz2', '56348.ds.bz2', '244197.ds.bz2', '8877.ds.bz2', '118215.ds.bz2', '186072.ds.bz2', '266563.ds.bz2', '24397.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.577
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  363
# ['285683.ds.bz2', '235389.ds.bz2', '35017.ds.bz2', '244271.ds.bz2', '370553.ds.bz2', '64295.ds.bz2', '63773.ds.bz2', '26638.ds.bz2', '26257.ds.bz2', '95095.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.338
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  364
# ['413509.ds.bz2', '17463.ds.bz2', '111163.ds.bz2', '389410.ds.bz2', '56518.ds.bz2', '2380.ds.bz2', '108029.ds.bz2', '426673.ds.bz2', '208895.ds.bz2', '403483.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.753
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  365
# ['423938.ds.bz2', '137390.ds.bz2', '432910.ds.bz2', '343382.ds.bz2', '40813.ds.bz2', '438928.ds.bz2', '373606.ds.bz2', '288708.ds.bz2', '262357.ds.bz2', '44195.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.822
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  366
# ['121571.ds.bz2', '353423.ds.bz2', '24058.ds.bz2', '155356.ds.bz2', '310250.ds.bz2', '7982.ds.bz2', '295.ds.bz2', '19550.ds.bz2', '372958.ds.bz2', '309131.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.701
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  367
# ['17630.ds.bz2', '250193.ds.bz2', '145820.ds.bz2', '221923.ds.bz2', '157988.ds.bz2', '61325.ds.bz2', '331163.ds.bz2', '142908.ds.bz2', '129617.ds.bz2', '253496.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.125
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  368
# ['31757.ds.bz2', '41541.ds.bz2', '114556.ds.bz2', '368193.ds.bz2', '185646.ds.bz2', '31317.ds.bz2', '161502.ds.bz2', '99492.ds.bz2', '35785.ds.bz2', '81449.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.406
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  369
# ['224349.ds.bz2', '120227.ds.bz2', '34399.ds.bz2', '39622.ds.bz2', '18763.ds.bz2', '19858.ds.bz2', '362054.ds.bz2', '401225.ds.bz2', '155855.ds.bz2', '433744.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.276
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  370
# ['3660.ds.bz2', '6293.ds.bz2', '233385.ds.bz2', '436558.ds.bz2', '287190.ds.bz2', '43348.ds.bz2', '26799.ds.bz2', '291395.ds.bz2', '2020.ds.bz2', '12642.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.962
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  371
# ['390793.ds.bz2', '122084.ds.bz2', '365912.ds.bz2', '54255.ds.bz2', '46186.ds.bz2', '361020.ds.bz2', '181185.ds.bz2', '339108.ds.bz2', '33301.ds.bz2', '275161.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.025
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  372
# ['154003.ds.bz2', '186343.ds.bz2', '95948.ds.bz2', '252733.ds.bz2', '289446.ds.bz2', '142420.ds.bz2', '61401.ds.bz2', '81870.ds.bz2', '212006.ds.bz2', '337519.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.038
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  373
# ['441109.ds.bz2', '21414.ds.bz2', '17440.ds.bz2', '250196.ds.bz2', '137415.ds.bz2', '42195.ds.bz2', '6735.ds.bz2', '3611.ds.bz2', '428545.ds.bz2', '300917.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.053
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  374
# ['370405.ds.bz2', '10080.ds.bz2', '37179.ds.bz2', '16048.ds.bz2', '104798.ds.bz2', '293439.ds.bz2', '6522.ds.bz2', '310419.ds.bz2', '340080.ds.bz2', '300398.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.806
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  375
# ['42493.ds.bz2', '275250.ds.bz2', '407601.ds.bz2', '41786.ds.bz2', '4193.ds.bz2', '12892.ds.bz2', '18825.ds.bz2', '29940.ds.bz2', '424340.ds.bz2', '299801.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.911
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  376
# ['181652.ds.bz2', '241519.ds.bz2', '18636.ds.bz2', '326995.ds.bz2', '158907.ds.bz2', '317204.ds.bz2', '408402.ds.bz2', '415829.ds.bz2', '175736.ds.bz2', '39882.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.790
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  377
# ['100347.ds.bz2', '34608.ds.bz2', '418022.ds.bz2', '26551.ds.bz2', '56627.ds.bz2', '2248.ds.bz2', '35934.ds.bz2', '266127.ds.bz2', '29430.ds.bz2', '99696.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.777
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  378
# ['437924.ds.bz2', '222448.ds.bz2', '285850.ds.bz2', '308351.ds.bz2', '397475.ds.bz2', '5498.ds.bz2', '409345.ds.bz2', '126676.ds.bz2', '422662.ds.bz2', '23192.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.825
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  379
# ['427820.ds.bz2', '18083.ds.bz2', '153363.ds.bz2', '20122.ds.bz2', '119071.ds.bz2', '27034.ds.bz2', '261914.ds.bz2', '4430.ds.bz2', '169893.ds.bz2', '163424.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.940
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  380
# ['373096.ds.bz2', '27584.ds.bz2', '28464.ds.bz2', '329505.ds.bz2', '22759.ds.bz2', '66569.ds.bz2', '427464.ds.bz2', '59691.ds.bz2', '120180.ds.bz2', '235801.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.169
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  381
# ['19558.ds.bz2', '101946.ds.bz2', '363044.ds.bz2', '310433.ds.bz2', '304508.ds.bz2', '45858.ds.bz2', '32136.ds.bz2', '281795.ds.bz2', '157008.ds.bz2', '411576.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.085
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  382
# ['333368.ds.bz2', '275140.ds.bz2', '438374.ds.bz2', '170217.ds.bz2', '278497.ds.bz2', '29733.ds.bz2', '30075.ds.bz2', '7056.ds.bz2', '161429.ds.bz2', '3831.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.822
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  383
# ['173598.ds.bz2', '11121.ds.bz2', '404359.ds.bz2', '327995.ds.bz2', '380949.ds.bz2', '42492.ds.bz2', '112914.ds.bz2', '1605.ds.bz2', '121245.ds.bz2', '118644.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.124
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  384
# ['1597.ds.bz2', '85253.ds.bz2', '310588.ds.bz2', '6614.ds.bz2', '111486.ds.bz2', '264496.ds.bz2', '52908.ds.bz2', '95558.ds.bz2', '426961.ds.bz2', '135683.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.804
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  385
# ['430419.ds.bz2', '160287.ds.bz2', '18702.ds.bz2', '40861.ds.bz2', '114149.ds.bz2', '118833.ds.bz2', '407110.ds.bz2', '44314.ds.bz2', '381295.ds.bz2', '325505.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.288
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  386
# ['41082.ds.bz2', '220603.ds.bz2', '307284.ds.bz2', '24732.ds.bz2', '94804.ds.bz2', '133952.ds.bz2', '262996.ds.bz2', '50368.ds.bz2', '106532.ds.bz2', '152843.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.000
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  387
# ['380870.ds.bz2', '274502.ds.bz2', '42914.ds.bz2', '24897.ds.bz2', '411161.ds.bz2', '296735.ds.bz2', '6794.ds.bz2', '102021.ds.bz2', '120989.ds.bz2', '174048.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.829
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  388
# ['4804.ds.bz2', '29994.ds.bz2', '191556.ds.bz2', '168294.ds.bz2', '13581.ds.bz2', '279787.ds.bz2', '32323.ds.bz2', '84441.ds.bz2', '141753.ds.bz2', '86952.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.188
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  389
# ['151375.ds.bz2', '31627.ds.bz2', '279113.ds.bz2', '120505.ds.bz2', '158373.ds.bz2', '28566.ds.bz2', '115128.ds.bz2', '31835.ds.bz2', '13679.ds.bz2', '282181.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.985
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  390
# ['83729.ds.bz2', '15608.ds.bz2', '171380.ds.bz2', '120396.ds.bz2', '26975.ds.bz2', '68178.ds.bz2', '369812.ds.bz2', '281973.ds.bz2', '281290.ds.bz2', '165043.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.583
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  391
# ['4236.ds.bz2', '146431.ds.bz2', '107921.ds.bz2', '21162.ds.bz2', '16762.ds.bz2', '128603.ds.bz2', '392538.ds.bz2', '46233.ds.bz2', '328961.ds.bz2', '410258.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.834
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  392
# ['316640.ds.bz2', '33128.ds.bz2', '407205.ds.bz2', '379440.ds.bz2', '279792.ds.bz2', '205511.ds.bz2', '16686.ds.bz2', '408598.ds.bz2', '19743.ds.bz2', '12562.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.030
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  393
# ['232519.ds.bz2', '58954.ds.bz2', '37291.ds.bz2', '9981.ds.bz2', '32094.ds.bz2', '68323.ds.bz2', '423376.ds.bz2', '44780.ds.bz2', '11899.ds.bz2', '32621.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.855
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  394
# ['395483.ds.bz2', '198690.ds.bz2', '25211.ds.bz2', '12439.ds.bz2', '393923.ds.bz2', '284363.ds.bz2', '12279.ds.bz2', '101381.ds.bz2', '279561.ds.bz2', '316732.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.822
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  395
# ['311396.ds.bz2', '441377.ds.bz2', '150863.ds.bz2', '432188.ds.bz2', '2746.ds.bz2', '434583.ds.bz2', '427130.ds.bz2', '236819.ds.bz2', '97865.ds.bz2', '22118.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.623
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  396
# ['1705.ds.bz2', '3899.ds.bz2', '414873.ds.bz2', '41130.ds.bz2', '286475.ds.bz2', '23129.ds.bz2', '63264.ds.bz2', '177564.ds.bz2', '40701.ds.bz2', '4434.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 2.175
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  397
# ['7608.ds.bz2', '39946.ds.bz2', '28616.ds.bz2', '43051.ds.bz2', '21107.ds.bz2', '22603.ds.bz2', '34604.ds.bz2', '224889.ds.bz2', '107527.ds.bz2', '352449.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.609
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  398
# ['366561.ds.bz2', '23302.ds.bz2', '320955.ds.bz2', '80182.ds.bz2', '50044.ds.bz2', '37887.ds.bz2', '113656.ds.bz2', '316744.ds.bz2', '3137.ds.bz2', '152252.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.339
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  399
# ['437562.ds.bz2', '81397.ds.bz2', '441054.ds.bz2', '309367.ds.bz2', '344769.ds.bz2', '10074.ds.bz2', '12064.ds.bz2', '305242.ds.bz2', '261378.ds.bz2', '45157.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.483
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  400
# ['409443.ds.bz2', '30433.ds.bz2', '430372.ds.bz2', '200198.ds.bz2', '15900.ds.bz2', '247623.ds.bz2', '143719.ds.bz2', '149391.ds.bz2', '234660.ds.bz2', '151156.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.835
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  401
# ['9122.ds.bz2', '4876.ds.bz2', '404804.ds.bz2', '23272.ds.bz2', '14302.ds.bz2', '949.ds.bz2', '8767.ds.bz2', '26322.ds.bz2', '174565.ds.bz2', '3166.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.262
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  402
# ['39870.ds.bz2', '312300.ds.bz2', '42984.ds.bz2', '398075.ds.bz2', '416424.ds.bz2', '196034.ds.bz2', '28375.ds.bz2', '316696.ds.bz2', '43535.ds.bz2', '294274.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.215
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  403
# ['13592.ds.bz2', '30356.ds.bz2', '293518.ds.bz2', '5046.ds.bz2', '18023.ds.bz2', '15186.ds.bz2', '245648.ds.bz2', '4192.ds.bz2', '44370.ds.bz2', '1697.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 0.765
# Weights Saved:  outputs/train_nnet_t968556199949.p
# Batch:  404
# ['334521.ds.bz2', '41299.ds.bz2', '81396.ds.bz2', '39491.ds.bz2', '201256.ds.bz2', '436187.ds.bz2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# Avg. time taken by 1 file(1 iteration): 1.010
# Weights Saved:  outputs/train_nnet_t968556199949.p
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-41-61e6dc5c513d> in <module>()
#       2 # tips: try increasing iterations per batch
#       3 trainingStatus = defaultdict(lambda: bool(False)) # Reset it after 3 epochs of full-training set
# ----> 4 train.__next__()
#       5 playBeep()
#
# StopIteration:

# %%
# Test on training set
test(loaded_SKT, loaded_DCS, n_testSet=100, _testFiles=TrainFiles, n_checkpt = 10)
playBeep()

# %%
# POST TEST 1K SET
_ = test(loaded_SKT, loaded_DCS, n_testSet = -1, _testFiles = TestFiles, n_checkpt = 50)
playBeep()
# Out:
# 0  Checkpoint...
# 50  Checkpoint...
# 100  Checkpoint...
# 150  Checkpoint...
# 200  Checkpoint...
# 250  Checkpoint...
# 300  Checkpoint...
# 350  Checkpoint...
# 400  Checkpoint...
# 450  Checkpoint...
# 500  Checkpoint...
# 550  Checkpoint...
# 600  Checkpoint...
# 650  Checkpoint...
# Avg. Micro Recall of Lemmas: 0.8369512331454708
# Avg. Micro Recall of Words: 0.6885798895409492
# Avg. Micro Precision of Lemmas: 0.78979303122867
# Avg. Micro Precision of Words: 0.6511872539596757

# %%
# Test on Larger Set
_ = test(loaded_SKT, loaded_DCS, n_testSet = 3000, _testFiles = TestFiles_2, n_checkpt = 100)
playBeep()

# %%
# Out:
# Weights Saved:  outputs/train_nnet_t526539685574.p

# %%
trainer.neuralnet.W

# %%
trainer.neuralnet.U

# %%
for fn in TestFiles[:10]:
    _ = trainer.Test(loaded_SKT[fn], loaded_DCS[fn])
# Out:
# Get Edge Features Time:  6.570472478866577
# Get Edge Features Time:  1.6002552509307861
# Get Edge Features Time:  0.5128428936004639
# Get Edge Features Time:  0.16260337829589844
# Get Edge Features Time:  0.30678248405456543
# Get Edge Features Time:  1.3092880249023438
# Get Edge Features Time:  0.8916211128234863
# Get Edge Features Time:  1.8754069805145264
# Get Edge Features Time:  1.14072585105896
# Get Edge Features Time:  0.27155017852783203

# %%
WD.word_definite_extInit(matDB)
# node2 = WD.word_definite('tIkzRam', 'tIkzRa', 31, 0, 0)
node1 = WD.word_definite('Adi', 'Adi', 31, 0, 0)
node2 = WD.word_definite('ca', 'ca', 2, 0, 1)
# node1 = WD.word_definite('koRam', 'koRa', 31, 0, 1)
print(node1)
print(node2)

feats = WD.Get_Features(node1, node2)
print(feats.shape)
# Out:
# WD_Node[C: 0, P: 0, Adi @(31) => Adi]
# WD_Node[C: 1, P: 0, ca @(2) => ca]
# (1000, 1)

# %%
Wmat
# Out:
# array([[ 0.        ,  0.44093286,  0.54536647,  0.26590788,  0.89111612,
#          0.33948032, -0.03414859],
#        [ 0.84916065,  0.        ,  1.1908067 ,  1.00455444,  1.54897616,
#          0.94725297,  1.38592746],
#        [-0.40401637, -0.45824241,  0.        , -0.66569737,  0.02653288,
#         -0.6492698 , -0.28316029],
#        [-0.28461703, -0.35128149, -0.57814776,  0.        ,  0.53596003,
#         -0.61933034, -0.76127807],
#        [ 0.50401231,  0.48448779,  1.19736903,  0.747994  ,  0.        ,
#          0.75652086,  1.44398605],
#        [ 0.22824487,  0.24474065,  0.41312113,  0.37012238,  0.5754286 ,
#          0.        ,  0.5124145 ],
#        [-0.39726662, -0.46351106, -0.49387717, -0.53360749, -0.06269749,
#         -0.61960008,  0.        ]])

# %%
# Out:
# 0

# %% [markdown]
# ######   THE END
# -----------------------------------------------------------------------
