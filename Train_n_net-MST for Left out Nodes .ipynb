# %%
# %load_ext autoreload
# %autoreload 2

# %%
## bUILT-iN pACKAGES
import pickle
from collections import defaultdict
import json
import numpy as np
import math
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True)
# %matplotlib inline
from IPython.display import display

## lAST sUMMER
from romtoslp import *
from sentences import *
from DCS import *
import MatDB

## lAST yEAR
# from word_definite import *
# from nnet import *
# from heap_n_PrimMST import *
# from word_definite import *

# %%
import winsound
def playBeep():
    for i in range(3):
        winsound.Beep(2200, 300)
        winsound.Beep(2600, 300)

# %%
loaded_SKT = pickle.load(open('../Simultaneous_CompatSKT_10K.p', 'rb'), encoding=u'utf-8')
loaded_DCS = pickle.load(open('../Simultaneous_DCS_10K.p', 'rb'), encoding=u'utf-8')

# %%
dataset_4k_1k = pickle.load(open('../SmallDataset_4K_1K.p', 'rb'))
TrainFiles = dataset_4k_1k['TrainFiles']
TestFiles = dataset_4k_1k['TestFiles']

dataset_6k_3k = pickle.load(open('../SmallDataset_6K_3K.p', 'rb'))
TrainFiles_2 = dataset_6k_3k['TrainFiles']
TestFiles_2 = dataset_6k_3k['TestFiles']

# %%
matDB = MatDB.MatDB()

# %%
# from MatDB import *
import word_definite as WD
from heap_n_PrimMST import *
from nnet import *
"""
################################################################################################
######################  CREATE SEVERAL DATA STRUCTURES FROM SENTENCE/DCS  ######################
###########################  NODELIST, ADJACENCY LIST, GRAPH, HEAP #############################
################################################################################################
"""
def GetTrainingKit(sentenceObj, dcsObj):
    nodelist = GetNodes(sentenceObj)
    
    # Nodelist with only the correct_nodes
    nodelist2 = GetNodes(sentenceObj)
    nodelist2_to_correct_mapping = {}
    nodelist_correct = []
    search_key = 0
    first_key = 0
    for chunk_id in range(len(dcsObj.lemmas)):
        while nodelist2[first_key].chunk_id != chunk_id:
            first_key += 1
        for j in range(len(dcsObj.lemmas[chunk_id])):
            search_key = first_key
            while (nodelist2[search_key].lemma != rom_slp(dcsObj.lemmas[chunk_id][j])) or (nodelist2[search_key].cng != dcsObj.cng[chunk_id][j]):
                search_key += 1
                if search_key >= len(nodelist2) or nodelist2[search_key].chunk_id > chunk_id:
                    break
    #         print((rom_slp(dcsObj.lemmas[chunk_id][j]), dcsObj.cng[chunk_id][j]))
    #         print(nodelist[search_key])
            nodelist2_to_correct_mapping[len(nodelist_correct)] = search_key
            nodelist_correct.append(nodelist2[search_key])
    return (nodelist, nodelist_correct, nodelist2_to_correct_mapping)
    

def GetGraph(nodelist, neuralnet):
    if not neuralnet.outer_relu:
        conflicts_Dict = Get_Conflicts(nodelist)

        featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)

        (WScalarMat, SigmoidGateOutput) = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        return (conflicts_Dict, featVMat, WScalarMat, SigmoidGateOutput)
    else:
        conflicts_Dict = Get_Conflicts(nodelist)

        featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)

        WScalarMat = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        return (conflicts_Dict, featVMat, WScalarMat)

# %%
import time
st = str(int((time.time() * 1e6) % 1e13))
log_name = 'logs/train_nnet_t{}.out'.format(st)
p_name = 'outputs/train_nnet_t{}.p'.format(st)
print(p_name)
# outputs/train_nnet_t9543323920940.p - 80%
# Out:
# outputs/train_nnet_t322257505324.p

# %%
trainingStatus = defaultdict(lambda: bool(False))

# %%
"""
################################################################################################
##############################  MAIN FUNCTION  #################################################
################################################################################################
"""

def train(loaded_SKT, loaded_DCS, n_trainset = -1):
    # Train
    filePerBatch = 20
    iterationPerBatch = 10
    if n_trainset == -1:
        totalBatchToTrain = 20
    else:
        totalBatchToTrain = math.ceil(n_trainset/filePerBatch)
    
    for iterout in range(totalBatchToTrain):
        # Change current batch
        trainer.Save(p_name)
        print('Batch: ', iterout)
        files_for_batch = TrainFiles[iterout*filePerBatch:(iterout + 1)*filePerBatch]
        print(files_for_batch)
        # trainer.Load('outputs/neuralnet_trained.p')
        
        # Run few times on same set of files
        for iterin in range(iterationPerBatch):
            print('ITERATION IN', iterin)        
            for fn in files_for_batch:
                sentenceObj = loaded_SKT[fn]
                dcsObj = loaded_DCS[fn]
                if trainingStatus[sentenceObj.sent_id]:
                    continue
                # trainer.Save('outputs/saved_trainer.p')
                try:
                    trainer.Train(sentenceObj, dcsObj)
                except (IndexError, KeyError) as e:
                    print('\x1b[31mFailed: {} \x1b[0m'.format(sentenceObj.sent_id))
    trainer.Save(p_name)
                
def test(loaded_SKT, loaded_DCS, n_testSet = -1, _testFiles = None, old_Tester = False):
    total_lemma = 0;
    correct_lemma = 0;

    total_word = 0;
    total_output_nodes = 0
    correct_word = 0;
    file_counter = 0
    if _testFiles is None:
        if n_testSet == -1:
            _testFiles = TestFiles
        else:
            _testFiles = TestFiles[0:n_testSet]
    else:
        if n_testSet == -1:
            _testFiles = _testFiles
        else:
            _testFiles = _testFiles[0:n_testSet]
    
    recalls = []
    recalls_of_word = []
    precisions = []
    precisions_of_words = []
    for fn in _testFiles:
        if file_counter % 100 == 0:
            print(file_counter,' Checkpoint... ')
        file_counter += 1
        sentenceObj = loaded_SKT[fn]
        dcsObj = loaded_DCS[fn]        
        try:
            if old_Tester:
                (word_match, lemma_match, n_dcsWords, n_output_nodes) = trainer.Test_Old(sentenceObj, dcsObj)
            else:
                (word_match, lemma_match, n_dcsWords, n_output_nodes) = trainer.Test(sentenceObj, dcsObj)
            
            recalls.append(lemma_match/n_dcsWords)
            recalls_of_word.append(word_match/n_dcsWords)
            
            precisions.append(lemma_match/n_output_nodes)
            precisions_of_words.append(word_match/n_output_nodes)
            
            total_lemma += n_dcsWords
            total_word += n_dcsWords
            
            total_output_nodes += n_output_nodes            
            
            correct_lemma += lemma_match
            correct_word += word_match
        except (IndexError, KeyError) as e:
            print('Failed!')        

    print('Micro Recall[lemma]: {}'.format(100*correct_lemma/total_word))
    print('Micro Recall[word]: {}'.format(100*correct_word/total_word))
    print()
    print('Micro Precision[lemma]: {}'.format(100*correct_lemma/total_output_nodes))
    print('Micro Precision[word]: {}'.format(100*correct_word/total_output_nodes))
    print()
    print('Avg. Recall of Lemmas: {}'.format(np.mean(np.array(recalls))))
    print('Avg. Recall of Words: {}'.format(np.mean(np.array(recalls_of_word))))
    print('Avg. Precision of Lemmas: {}'.format(np.mean(np.array(precisions))))
    print('Avg. Precision of Words: {}'.format(np.mean(np.array(precisions_of_words))))
    
    return (recalls, recalls_of_word, precisions, precisions_of_words)

# %%
# NOW-OLD FUNCTION
# def GetLoss(_mst_adj_graph, _mask_de_correct_edges, _negLogLikelies):
#     _negLogLikelies = _negLogLikelies.copy()
#     _negLogLikelies[~_mst_adj_graph] = 0
#     _negLogLikelies[~_mask_de_correct_edges] *= -1 # BAKA!!! Check before you try to fix this again
#     return np.sum(_negLogLikelies)    

# NEW FUNCTION
def GetLoss(_mst_adj_graph, _mask_de_correct_edges, _WScalarMat):
    _WScalarMat = _WScalarMat.copy()
    _WScalarMat[_mst_adj_graph&(~_mask_de_correct_edges)] *= -1 # BAKA!!! Check before you try to fix this again
    _WScalarMat[~_mst_adj_graph] = 0
    return np.sum(_WScalarMat)

# %%
class Trainer:
    def __init__(self):
        self.hidden_layer_size = 400
        self._edge_vector_dim = WD._edge_vector_dim
        self._full_cnglist = list(WD.mat_cngCount_1D)
        self.neuralnet = NN(self._edge_vector_dim, self.hidden_layer_size, outer_relu=True)
        self.history = defaultdict(lambda: list())
        
    def Reset(self):
        self.neuralnet = NN(self._edge_vector_dim, self.hidden_layer_size)
        self.history = defaultdict(lambda: list())
        
    def Save(self, filename):
        #pickle.dump({'nnet': self.neuralnet, 'history': dict(self.history)}, open(filename, 'wb'))
        return
        
    
    def Load(self, filename):
        loader = pickle.load(open(filename, 'rb'))
        self.neuralnet.U = loader['U']
        self.neuralnet.W = loader['W']
    def Test_Old(self, sentenceObj, dcsObj):
        neuralnet = self.neuralnet
        minScore = np.inf
        minMst = None
        try:
            (nodelist, nodelist_correct, _) = GetTrainingKit(sentenceObj, dcsObj)
            # nodelist = GetNodes(sentenceObj)
        except IndexError:
            print('\x1b[31mError with {} \x1b[0m'.format(sentenceObj.sent_id))
            return (0, 0, 0)
            
        conflicts_Dict = Get_Conflicts(nodelist)
        conflicts_Dict_correct = Get_Conflicts(nodelist_correct)
        
        featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)
        featVMat_correct = Get_Feat_Vec_Matrix(nodelist_correct, conflicts_Dict_correct)
        
        if not self.neuralnet.outer_relu:
            (WScalarMat, SigmoidGateOutput) = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        else:
            WScalarMat = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        # print(WScalarMat)
        # Get all MST
        for source in range(len(nodelist)):
            (mst_nodes, mst_adj_graph) = MST(nodelist, WScalarMat, conflicts_Dict, source)
            # print('.', end = '')
            score = GetMSTWeight(mst_nodes, WScalarMat)
            if(score < minScore):
                minScore = score
                minMst = mst_nodes
        dcsLemmas = [[rom_slp(l) for l in arr]for arr in dcsObj.lemmas]
        word_match = 0
        lemma_match = 0
        n_output_nodes = 0
        for chunk_id, wdSplit in minMst.items():
            for wd in wdSplit:
                n_output_nodes += 1
                # Match lemma
                search_result = [i for i, j in enumerate(dcsLemmas[chunk_id]) if j == wd.lemma]
                if len(search_result) > 0:
                    lemma_match += 1
                # Match CNG
                for i in search_result:
                    if(dcsObj.cng[chunk_id][i] == str(wd.cng)):
                        word_match += 1
                        # print(wd.lemma, wd.cng)
                        break
        dcsLemmas = [l for arr in dcsObj.lemmas for l in arr]
#         print('\nFull Match: {}, Partial Match: {}, OutOf {}, NodeCount: {}, '.\
#               format(word_match, lemma_match, len(dcsLemmas), len(nodelist)))
        return (word_match, lemma_match, len(dcsLemmas), n_output_nodes)
        
    def Test(self, sentenceObj, dcsObj):
        neuralnet = self.neuralnet
        minScore = np.inf
        minMst = None
        try:
            (nodelist, nodelist_correct, _) = GetTrainingKit(sentenceObj, dcsObj)
            # nodelist = GetNodes(sentenceObj)
        except IndexError:
            print('\x1b[31mError with {} \x1b[0m'.format(sentenceObj.sent_id))
            return (0, 0, 0)
            
        conflicts_Dict = Get_Conflicts(nodelist)
        conflicts_Dict_correct = Get_Conflicts(nodelist_correct)
        
        featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)
        featVMat_correct = Get_Feat_Vec_Matrix(nodelist_correct, conflicts_Dict_correct)
        
        if not self.neuralnet.outer_relu:
            (WScalarMat, SigmoidGateOutput) = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        else:
            WScalarMat = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
        # print(WScalarMat)
        # Get all MST
        
        total_mst_computed = 0
        left_out_nodes = list(range(len(nodelist)))
        while len(left_out_nodes) > 0:
            total_mst_computed += 1
            # print(left_out_nodes)
            source = left_out_nodes[0]
            (mst_nodes, mst_adj_graph) = MST(nodelist, WScalarMat, conflicts_Dict, source) # T_X
            # Remove those nodes which have occurred in some MST
            left_out_nodes.remove(left_out_nodes[0])
            for lon_index in np.where(np.sum(mst_adj_graph, axis=0) > 0)[0]:
                if lon_index in left_out_nodes:
                    left_out_nodes.remove(lon_index)
            
            # print('.', end = '')
            # score = GetMSTWeight(mst_nodes, WScalarMat)
            score = np.sum(WScalarMat[mst_adj_graph])
            if(score < minScore):
                minScore = score
                minMst = mst_nodes
        dcsLemmas = [[rom_slp(l) for l in arr]for arr in dcsObj.lemmas]
        word_match = 0
        lemma_match = 0
        n_output_nodes = 0
        for chunk_id, wdSplit in minMst.items():
            for wd in wdSplit:
                n_output_nodes += 1
                # Match lemma
                search_result = [i for i, j in enumerate(dcsLemmas[chunk_id]) if j == wd.lemma]
                if len(search_result) > 0:
                    lemma_match += 1
                # Match CNG
                for i in search_result:
                    if(dcsObj.cng[chunk_id][i] == str(wd.cng)):
                        word_match += 1
                        # print(wd.lemma, wd.cng)
                        break
        dcsLemmas = [l for arr in dcsObj.lemmas for l in arr]
#         print('\nFull Match: {}, Partial Match: {}, OutOf {}, NodeCount: {}, MST_Computed: {}'.\
#               format(word_match, lemma_match, len(dcsLemmas), len(nodelist), total_mst_computed))
        return (word_match, lemma_match, len(dcsLemmas), n_output_nodes)
    
    def Train(self, sentenceObj, dcsObj):
        # Hyperparameter for hinge loss: m
        M_hinge = 14
        try:
            (nodelist, nodelist_correct, nodelist_to_correct_mapping) = GetTrainingKit(sentenceObj, dcsObj)
        except IndexError as e:
            # print('\x1b[31mError with {} \x1b[0m'.format(sentenceObj.sent_id))
            # print(e)
            return
        
        """ CREATE A MASK FOR ALL EDGES BETWEEN CORRECT NODE PAIRS"""
        mask_de_correct_edges = np.ndarray((len(nodelist), len(nodelist)), np.bool)*False
        for n1 in nodelist_to_correct_mapping.values():
            for n2 in nodelist_to_correct_mapping.values():
                if n1 != n2:
                    mask_de_correct_edges[n1, n2] = 1
                    mask_de_correct_edges[n2, n1] = 1
                
        
        """ FOR MST OF GRAPH WITH ONLY CORRECT SET OF NODES """
        if not self.neuralnet.outer_relu:
            (conflicts_Dict_correct, featVMat_correct, WScalarMat_correct, _) = GetGraph(nodelist_correct, self.neuralnet)
        else:
            (conflicts_Dict_correct, featVMat_correct, WScalarMat_correct) = GetGraph(nodelist_correct, self.neuralnet)
        source = 0
        (mst_nodes_correct, mst_adj_graph_correct_0) = MST(nodelist_correct, WScalarMat_correct, conflicts_Dict_correct, source)
        
        
        
        """ FOR ALL POSSIBLE MST FROM THE COMPLETE GRAPH """
        if not self.neuralnet.outer_relu:
            (conflicts_Dict, featVMat, WScalarMat, SigmoidGateOutput) = GetGraph(nodelist, self.neuralnet)
        else:
            (conflicts_Dict, featVMat, WScalarMat) = GetGraph(nodelist, self.neuralnet)
        Total_Loss = 0

        Loss_2 = np.sum(WScalarMat*mask_de_correct_edges - WScalarMat*(~mask_de_correct_edges))
        
        # Convert correct spanning tree graph adj matrix to actual marix dimensions
        # Create full-size adjacency matrix for correct_mst
        nodelen = len(nodelist)
        mst_adj_graph_correct = np.ndarray((nodelen, nodelen), np.bool)*False # T_STAR
        for i in range(mst_adj_graph_correct_0.shape[0]):
            for j in range(mst_adj_graph_correct_0.shape[1]):
                mst_adj_graph_correct[nodelist_to_correct_mapping[i], nodelist_to_correct_mapping[j]] = \
                mst_adj_graph_correct_0[i, j]

        # print(WScalarMat)

        """ For each node - Find MST with that source"""
        dLdOut = np.zeros(WScalarMat.shape)
        
        worst_Tx = None
        worst_graph_dist = 0
        
#         best_Tx = None
#         best_graph_dist = np.inf
        
        left_out_nodes = list(range(len(nodelist)))
        while len(left_out_nodes) > 0:
            source = left_out_nodes[0]
            (mst_nodes, mst_adj_graph) = MST(nodelist, WScalarMat, conflicts_Dict, source) # T_X
            # Remove those nodes which have occurred in some MST
            left_out_nodes.remove(left_out_nodes[0])
            for lon_index in np.where(np.sum(mst_adj_graph, axis=0) > 0)[0]:
                if lon_index in left_out_nodes:
                    left_out_nodes.remove(lon_index)
#             print('.', end = '')
            
            graph_dist = np.sum(mst_adj_graph&(~mst_adj_graph_correct))
            if graph_dist > worst_graph_dist:
                worst_graph_dist = graph_dist
                worst_Tx = mst_adj_graph
#             if graph_dist < best_graph_dist:
#                 best_graph_dist = graph_dist
#                 best_Tx = mst_adj_graph
            # Energy diff should all be negative
#             print('Source: [{}], Graph_Dist: {}, Energy: {:.2f}, Energy Diff: {:.2f}'.format(source, graph_dist,  np.sum(WScalarMat[mst_adj_graph]),\
#                                                                 np.sum(WScalarMat[mst_adj_graph_correct]) - np.sum(WScalarMat[mst_adj_graph])))
            
            # Total_Loss += (W_star - GetMSTWeight(mst_nodes, WScalarMat))
            Total_Loss += GetLoss(mst_adj_graph, mask_de_correct_edges, WScalarMat)

        """ Gradient Descent """
        # FOR MOST OFFENdING Y
        doBpp = False
        worst_energy_diff = np.sum(WScalarMat[mst_adj_graph_correct]) - np.sum(WScalarMat[worst_Tx])
        if M_hinge + worst_energy_diff > 0:
            doBpp = True
            if not self.neuralnet.outer_relu:
                # For new loss function with sigmoid on neuralnet
                dLdOut_inner = (1 - SigmoidGateOutput)
                dLdOut_inner[~mst_adj_graph] = 0 # Edges not in the current tree
                dLdOut_inner[mst_adj_graph^mask_de_correct_edges] = -dLdOut_inner[mst_adj_graph^mask_de_correct_edges]

                dLdOut += dLdOut_inner
            else:
                # For new loss function with ReLU on neuralnet
                dLdOut_inner = np.zeros_like(WScalarMat)
                
                dLdOut_inner[mst_adj_graph_correct] = 1
                dLdOut_inner[worst_Tx] -= 1

                dLdOut += dLdOut_inner
                
#         best_energy_diff = np.sum(WScalarMat[best_Tx]) - np.sum(WScalarMat[mst_adj_graph_correct])
#         if M_hinge + best_energy_diff > 0:
#             doBpp = True
#             if not self.neuralnet.outer_relu:
#                 # For new loss function with sigmoid on neuralnet
#                 dLdOut_inner = (1 - SigmoidGateOutput)
#                 dLdOut_inner[~mst_adj_graph] = 0 # Edges not in the current tree
#                 dLdOut_inner[mst_adj_graph^mask_de_correct_edges] = -dLdOut_inner[mst_adj_graph^mask_de_correct_edges]

#                 dLdOut += dLdOut_inner
#             else:
#                 # For new loss function with ReLU on neuralnet
#                 dLdOut_inner = np.zeros_like(WScalarMat)
                
#                 dLdOut_inner[best_Tx] = 1
#                 dLdOut_inner[mst_adj_graph_correct] -= 1
                

#                 dLdOut += dLdOut_inner

        if doBpp:
            print('{}. '.format(sentenceObj.sent_id), end = '')
            self.neuralnet.Back_Prop(dLdOut, len(nodelist), featVMat)
        else:
            trainingStatus[sentenceObj.sent_id] = True # Means tranining done on this file
            #print('Don\'t do BPP')
            pass
        
        Total_Loss /= len(nodelist)
        self.history[sentenceObj.sent_id].append(Total_Loss)
#         print("\nFileKey: %s, Loss: %6.3f, Loss2: %6.3f" % (sentenceObj.sent_id, Total_Loss, Loss_2))

# %%
# trainer.neuralnet.U

# %%
trainer = None
def InitModule(_matDB):
    global WD, trainer
    WD.word_definite_extInit(_matDB)
    trainer = Trainer()
InitModule(matDB)
trainingStatus = defaultdict(lambda: bool(False))
# trainer.Load('outputs/train_nnet_t9745407094833.p')
# Out:
# 443

# %%
"""
################################################################################################
################################################################################################
################################################################################################
"""
# if __name__ == '__main__':
# loaded_SKT = pickle.load(open('../Simultaneous_CompatSKT_10K.p', 'rb'))
# loaded_DCS = pickle.load(open('../Simultaneous_DCS_10K.p', 'rb'))
# main(loaded_SKT, loaded_DCS)
np.set_printoptions(suppress=False)
trainer.Train(loaded_SKT['170095.p2'], loaded_DCS['170095.p2'])
# trainer.Test(loaded_SKT['170095.p2'], loaded_DCS['170095.p2'])
# print ("Not Implemented")
# Out:
# 170095. Max(delW):   0.000052	Max(delU):   0.000023

# %%
# Complete Training
trainingStatus = defaultdict(lambda: bool(False)) # Reset it after 3 epochs of full-training set
train(loaded_SKT, loaded_DCS, 3000)
playBeep()
# Out:
# Batch:  0
# ['141141.p2', '206744.p2', '30352.p2', '43009.p2', '5774.p2', '205691.p2', '216192.p2', '352667.p2', '59768.p2', '35561.p2', '433461.p2', '54567.p2', '165647.p2', '32144.p2', '410602.p2', '289063.p2', '236819.p2', '347229.p2', '24734.p2', '147078.p2']
# ITERATION IN 0
# 141141. Max(delW):   0.000041	Max(delU):   0.000021
# 206744. Max(delW):   0.000027	Max(delU):   0.000016
# 30352. Max(delW):   0.000063	Max(delU):   0.000063
# 43009. Max(delW):   0.000032	Max(delU):   0.000012
# 5774. Max(delW):   0.000036	Max(delU):   0.000013
# 352667. Max(delW):   0.000027	Max(delU):   0.000010
# 433461. Max(delW):   0.000061	Max(delU):   0.000015
# 54567. Max(delW):   0.000057	Max(delU):   0.000027
# 32144. Max(delW):   0.000031	Max(delU):   0.000005
# 289063. Max(delW):   0.000036	Max(delU):   0.000015
# 147078. Max(delW):   0.000016	Max(delU):   0.000002
# ITERATION IN 1
# 141141. Max(delW):   0.000040	Max(delU):   0.000007
# 206744. Max(delW):   0.000055	Max(delU):   0.000038
# 30352. Max(delW):   0.000044	Max(delU):   0.000031
# 43009. Max(delW):   0.000024	Max(delU):   0.000011
# 433461. Max(delW):   0.000079	Max(delU):   0.000036
# 54567. Max(delW):   0.000021	Max(delU):   0.000003
# 32144. Max(delW):   0.000020	Max(delU):   0.000005
# ITERATION IN 2
# 141141. Max(delW):   0.000047	Max(delU):   0.000009
# 433461. Max(delW):   0.000062	Max(delU):   0.000015
# 32144. Max(delW):   0.000020	Max(delU):   0.000005
# ITERATION IN 3
# 141141. Max(delW):   0.000035	Max(delU):   0.000009
# 32144. Max(delW):   0.000020	Max(delU):   0.000005
# ITERATION IN 4
# 141141. Max(delW):   0.000030	Max(delU):   0.000009
# 32144. Max(delW):   0.000018	Max(delU):   0.000004
# ITERATION IN 5
# 141141. Max(delW):   0.000034	Max(delU):   0.000009
# ITERATION IN 6
# 141141. Max(delW):   0.000030	Max(delU):   0.000009
# ITERATION IN 7
# 141141. Max(delW):   0.000033	Max(delU):   0.000009
# ITERATION IN 8
# 141141. Max(delW):   0.000031	Max(delU):   0.000009
# ITERATION IN 9
# Batch:  1
# ['345767.p2', '43597.p2', '153835.p2', '169097.p2', '32122.p2', '99734.p2', '128662.p2', '18398.p2', '167814.p2', '260958.p2', '97865.p2', '339958.p2', '93131.p2', '432551.p2', '106532.p2', '8032.p2', '171784.p2', '381991.p2', '88631.p2', '349070.p2']
# ITERATION IN 0
# 153835. 128662. Max(delW):   0.000035	Max(delU):   0.000007
# ITERATION IN 1
# 153835. 128662. Max(delW):   0.000052	Max(delU):   0.000015
# ITERATION IN 2
# 153835. 128662. Max(delW):   0.000053	Max(delU):   0.000015
# ITERATION IN 3
# 153835. 128662. Max(delW):   0.000055	Max(delU):   0.000015
# ITERATION IN 4
# 153835. 128662. Max(delW):   0.000060	Max(delU):   0.000019
# ITERATION IN 5
# 153835. 128662. Max(delW):   0.000056	Max(delU):   0.000015
# ITERATION IN 6
# 153835. 128662. Max(delW):   0.000052	Max(delU):   0.000015
# ITERATION IN 7
# 153835. 128662. Max(delW):   0.000049	Max(delU):   0.000020
# ITERATION IN 8
# 153835. 128662. Max(delW):   0.000056	Max(delU):   0.000016
# ITERATION IN 9
# 153835. 128662. Max(delW):   0.000055	Max(delU):   0.000016
# Batch:  2
# ['31848.p2', '418406.p2', '18320.p2', '82388.p2', '386667.p2', '54618.p2', '32180.p2', '390488.p2', '142845.p2', '36099.p2', '334555.p2', '313323.p2', '181418.p2', '433462.p2', '137872.p2', '419945.p2', '67433.p2', '22309.p2', '405434.p2', '39195.p2']
# ITERATION IN 0
# 31848. Max(delW):   0.000028	Max(delU):   0.000005
# 82388. Max(delW):   0.000029	Max(delU):   0.000005
# 54618. Max(delW):   0.000056	Max(delU):   0.000013
# 32180. Max(delW):   0.000050	Max(delU):   0.000006
# 313323. Max(delW):   0.000025	Max(delU):   0.000004
# 419945. ITERATION IN 1
# 31848. Max(delW):   0.000028	Max(delU):   0.000005
# 82388. Max(delW):   0.000030	Max(delU):   0.000005
# 54618. Max(delW):   0.000055	Max(delU):   0.000013
# 32180. Max(delW):   0.000046	Max(delU):   0.000006
# 313323. Max(delW):   0.000025	Max(delU):   0.000004
# 419945. ITERATION IN 2
# 31848. Max(delW):   0.000025	Max(delU):   0.000005
# 82388. Max(delW):   0.000024	Max(delU):   0.000005
# 54618. Max(delW):   0.000047	Max(delU):   0.000013
# 32180. Max(delW):   0.000046	Max(delU):   0.000006
# 419945. ITERATION IN 3
# 31848. Max(delW):   0.000023	Max(delU):   0.000005
# 82388. Max(delW):   0.000027	Max(delU):   0.000005
# 54618. Max(delW):   0.000046	Max(delU):   0.000013
# 32180. Max(delW):   0.000046	Max(delU):   0.000006
# 419945. ITERATION IN 4
# 31848. Max(delW):   0.000023	Max(delU):   0.000005
# 82388. Max(delW):   0.000030	Max(delU):   0.000005
# 54618. Max(delW):   0.000046	Max(delU):   0.000012
# 32180. Max(delW):   0.000046	Max(delU):   0.000006
# 419945. ITERATION IN 5
# 31848. Max(delW):   0.000029	Max(delU):   0.000005
# 82388. Max(delW):   0.000027	Max(delU):   0.000005
# 54618. Max(delW):   0.000046	Max(delU):   0.000012
# 32180. Max(delW):   0.000046	Max(delU):   0.000006
# 419945. ITERATION IN 6
# 31848. Max(delW):   0.000023	Max(delU):   0.000005
# 82388. Max(delW):   0.000025	Max(delU):   0.000005
# 54618. Max(delW):   0.000046	Max(delU):   0.000012
# 32180. Max(delW):   0.000039	Max(delU):   0.000006
# 419945. ITERATION IN 7
# 31848. Max(delW):   0.000023	Max(delU):   0.000005
# 82388. Max(delW):   0.000027	Max(delU):   0.000005
# 54618. Max(delW):   0.000046	Max(delU):   0.000012
# 32180. Max(delW):   0.000046	Max(delU):   0.000007
# 419945. ITERATION IN 8
# 31848. Max(delW):   0.000023	Max(delU):   0.000005
# 82388. Max(delW):   0.000027	Max(delU):   0.000005
# 54618. Max(delW):   0.000046	Max(delU):   0.000012
# 32180. Max(delW):   0.000043	Max(delU):   0.000007
# 419945. ITERATION IN 9
# 31848. Max(delW):   0.000023	Max(delU):   0.000005
# 82388. Max(delW):   0.000036	Max(delU):   0.000006
# 54618. Max(delW):   0.000046	Max(delU):   0.000011
# 32180. Max(delW):   0.000046	Max(delU):   0.000007
# 419945. Batch:  3
# ['356790.p2', '21008.p2', '115771.p2', '354417.p2', '69608.p2', '26681.p2', '52335.p2', '14039.p2', '133194.p2', '152280.p2', '71280.p2', '103056.p2', '66217.p2', '232261.p2', '343321.p2', '324245.p2', '327534.p2', '275190.p2', '276622.p2', '114120.p2']
# ITERATION IN 0
# 21008. Max(delW):   0.000021	Max(delU):   0.000002
# 354417. 52335. Max(delW):   0.000037	Max(delU):   0.000008
# ITERATION IN 1
# 21008. Max(delW):   0.000016	Max(delU):   0.000002
# 354417. 52335. Max(delW):   0.000030	Max(delU):   0.000008
# ITERATION IN 2
# 21008. Max(delW):   0.000016	Max(delU):   0.000002
# 354417. 52335. Max(delW):   0.000032	Max(delU):   0.000008
# ITERATION IN 3
# 21008. Max(delW):   0.000020	Max(delU):   0.000003
# 354417. 52335. Max(delW):   0.000033	Max(delU):   0.000008
# ITERATION IN 4
# 21008. Max(delW):   0.000019	Max(delU):   0.000003
# 354417. 52335. Max(delW):   0.000018	Max(delU):   0.000003
# ITERATION IN 5
# 21008. Max(delW):   0.000020	Max(delU):   0.000003
# 354417. 52335. Max(delW):   0.000017	Max(delU):   0.000003
# ITERATION IN 6
# 21008. Max(delW):   0.000019	Max(delU):   0.000003
# 354417. 52335. Max(delW):   0.000035	Max(delU):   0.000008
# ITERATION IN 7
# 21008. Max(delW):   0.000020	Max(delU):   0.000003
# 354417. 52335. Max(delW):   0.000016	Max(delU):   0.000003
# ITERATION IN 8
# 21008. Max(delW):   0.000019	Max(delU):   0.000003
# 354417. 52335. Max(delW):   0.000017	Max(delU):   0.000003
# ITERATION IN 9
# 21008. Max(delW):   0.000019	Max(delU):   0.000003
# 354417. 52335. Max(delW):   0.000023	Max(delU):   0.000003
# Batch:  4
# ['263875.p2', '379440.p2', '118226.p2', '269324.p2', '18238.p2', '332979.p2', '60196.p2', '9174.p2', '24061.p2', '12019.p2', '152857.p2', '26656.p2', '38895.p2', '333881.p2', '187328.p2', '24442.p2', '394845.p2', '340209.p2', '100234.p2', '12929.p2']
# ITERATION IN 0
# 263875. Max(delW):   0.000030	Max(delU):   0.000004
# 118226. Max(delW):   0.000026	Max(delU):   0.000005
# 269324. Max(delW):   0.000011	Max(delU):   0.000002
# 38895. Max(delW):   0.000026	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000031	Max(delU):   0.000004
# ITERATION IN 1
# 263875. Max(delW):   0.000036	Max(delU):   0.000004
# 118226. Max(delW):   0.000027	Max(delU):   0.000007
# 269324. Max(delW):   0.000010	Max(delU):   0.000002
# 38895. Max(delW):   0.000028	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000031	Max(delU):   0.000003
# ITERATION IN 2
# 263875. Max(delW):   0.000036	Max(delU):   0.000004
# 118226. Max(delW):   0.000035	Max(delU):   0.000007
# 269324. Max(delW):   0.000010	Max(delU):   0.000002
# 38895. Max(delW):   0.000031	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000031	Max(delU):   0.000003
# ITERATION IN 3
# 263875. Max(delW):   0.000027	Max(delU):   0.000004
# 118226. Max(delW):   0.000028	Max(delU):   0.000007
# 269324. Max(delW):   0.000010	Max(delU):   0.000002
# 38895. Max(delW):   0.000031	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000029	Max(delU):   0.000003
# ITERATION IN 4
# 263875. Max(delW):   0.000027	Max(delU):   0.000004
# 118226. Max(delW):   0.000028	Max(delU):   0.000007
# 269324. Max(delW):   0.000010	Max(delU):   0.000002
# 38895. Max(delW):   0.000024	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000030	Max(delU):   0.000003
# ITERATION IN 5
# 263875. Max(delW):   0.000027	Max(delU):   0.000004
# 118226. Max(delW):   0.000028	Max(delU):   0.000007
# 269324. Max(delW):   0.000011	Max(delU):   0.000002
# 38895. Max(delW):   0.000019	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000031	Max(delU):   0.000003
# ITERATION IN 6
# 263875. Max(delW):   0.000037	Max(delU):   0.000005
# 118226. Max(delW):   0.000030	Max(delU):   0.000007
# 269324. Max(delW):   0.000009	Max(delU):   0.000002
# 38895. Max(delW):   0.000023	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000029	Max(delU):   0.000003
# ITERATION IN 7
# 263875. Max(delW):   0.000037	Max(delU):   0.000005
# 269324. Max(delW):   0.000010	Max(delU):   0.000002
# 38895. Max(delW):   0.000031	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000031	Max(delU):   0.000003
# ITERATION IN 8
# 263875. Max(delW):   0.000037	Max(delU):   0.000005
# 269324. Max(delW):   0.000010	Max(delU):   0.000002
# 38895. Max(delW):   0.000024	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000031	Max(delU):   0.000003
# ITERATION IN 9
# 263875. Max(delW):   0.000037	Max(delU):   0.000005
# 269324. Max(delW):   0.000009	Max(delU):   0.000002
# 38895. Max(delW):   0.000021	Max(delU):   0.000003
# Failed: 333881
# 340209. Max(delW):   0.000029	Max(delU):   0.000003
# Batch:  5
# ['17480.p2', '43439.p2', '134245.p2', '127512.p2', '137676.p2', '438775.p2', '325505.p2', '56900.p2', '344242.p2', '22152.p2', '43291.p2', '9234.p2', '302299.p2', '259731.p2', '92676.p2', '19257.p2', '18279.p2', '135583.p2', '130103.p2', '163324.p2']
# ITERATION IN 0
# 137676. 135583. Max(delW):   0.000017	Max(delU):   0.000008
# ITERATION IN 1
# 137676. ITERATION IN 2
# 137676. ITERATION IN 3
# 137676. ITERATION IN 4
# 137676. ITERATION IN 5
# 137676. ITERATION IN 6
# 137676. ITERATION IN 7
# 137676. ITERATION IN 8
# 137676. ITERATION IN 9
# 137676. Batch:  6
# ['364481.p2', '29036.p2', '369328.p2', '179402.p2', '109001.p2', '17337.p2', '36352.p2', '135804.p2', '302174.p2', '4192.p2', '6395.p2', '285849.p2', '263129.p2', '40128.p2', '403816.p2', '356748.p2', '20118.p2', '127254.p2', '7431.p2', '212017.p2']
# ITERATION IN 0
# 285849. Max(delW):   0.000026	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000032	Max(delU):   0.000017
# ITERATION IN 1
# 285849. Max(delW):   0.000026	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000039	Max(delU):   0.000017
# ITERATION IN 2
# 285849. Max(delW):   0.000026	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000030	Max(delU):   0.000017
# ITERATION IN 3
# 285849. Max(delW):   0.000026	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000029	Max(delU):   0.000017
# ITERATION IN 4
# 285849. Max(delW):   0.000026	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000040	Max(delU):   0.000017
# ITERATION IN 5
# 285849. Max(delW):   0.000026	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000022	Max(delU):   0.000013
# ITERATION IN 6
# 285849. Max(delW):   0.000026	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000022	Max(delU):   0.000013
# ITERATION IN 7
# 285849. Max(delW):   0.000037	Max(delU):   0.000025
# 263129. 403816. Max(delW):   0.000024	Max(delU):   0.000013
# ITERATION IN 8
# 285849. Max(delW):   0.000025	Max(delU):   0.000003
# 263129. 403816. Max(delW):   0.000031	Max(delU):   0.000013
# ITERATION IN 9
# 285849. Max(delW):   0.000037	Max(delU):   0.000025
# 263129. 403816. Max(delW):   0.000022	Max(delU):   0.000009
# Batch:  7
# ['431249.p2', '146894.p2', '42903.p2', '43609.p2', '346784.p2', '243904.p2', '337637.p2', '32169.p2', '142708.p2', '298784.p2', '8603.p2', '383513.p2', '225357.p2', '338651.p2', '27251.p2', '4206.p2', '2636.p2', '116815.p2', '302798.p2', '347337.p2']
# ITERATION IN 0
# 431249. Max(delW):   0.000058	Max(delU):   0.000042
# 298784. Max(delW):   0.000028	Max(delU):   0.000005
# ITERATION IN 1
# 298784. Max(delW):   0.000030	Max(delU):   0.000015
# ITERATION IN 2
# 298784. Max(delW):   0.000030	Max(delU):   0.000015
# ITERATION IN 3
# ITERATION IN 4
# ITERATION IN 5
# ITERATION IN 6
# ITERATION IN 7
# ITERATION IN 8
# ITERATION IN 9
# Batch:  8
# ['25796.p2', '24183.p2', '15280.p2', '157677.p2', '403920.p2', '8497.p2', '84269.p2', '323034.p2', '31792.p2', '156457.p2', '44416.p2', '435925.p2', '34541.p2', '44307.p2', '15599.p2', '170095.p2', '39559.p2', '366428.p2', '39126.p2', '392658.p2']
# ITERATION IN 0
# 84269. 156457. 39559. Max(delW):   0.000021	Max(delU):   0.000003
# 392658. Max(delW):   0.000025	Max(delU):   0.000003
# ITERATION IN 1
# 84269. 156457. 39559. Max(delW):   0.000032	Max(delU):   0.000009
# 392658. Max(delW):   0.000015	Max(delU):   0.000003
# ITERATION IN 2
# 84269. 156457. 39559. Max(delW):   0.000032	Max(delU):   0.000009
# 392658. Max(delW):   0.000018	Max(delU):   0.000003
# ITERATION IN 3
# 84269. 156457. 39559. Max(delW):   0.000032	Max(delU):   0.000009
# 392658. Max(delW):   0.000015	Max(delU):   0.000003
# ITERATION IN 4
# 84269. 156457. 39559. Max(delW):   0.000023	Max(delU):   0.000007
# 392658. Max(delW):   0.000015	Max(delU):   0.000003
# ITERATION IN 5
# 84269. 156457. 39559. Max(delW):   0.000025	Max(delU):   0.000009
# 392658. Max(delW):   0.000036	Max(delU):   0.000004
# ITERATION IN 6
# 84269. 156457. 39559. Max(delW):   0.000031	Max(delU):   0.000011
# 392658. Max(delW):   0.000018	Max(delU):   0.000004
# ITERATION IN 7
# 84269. 156457. 39559. Max(delW):   0.000034	Max(delU):   0.000008
# 392658. Max(delW):   0.000018	Max(delU):   0.000003
# ITERATION IN 8
# 84269. 156457. 39559. Max(delW):   0.000032	Max(delU):   0.000008
# 392658. Max(delW):   0.000025	Max(delU):   0.000003
# ITERATION IN 9
# 84269. 156457. 39559. Max(delW):   0.000032	Max(delU):   0.000008
# 392658. Max(delW):   0.000018	Max(delU):   0.000003
# Batch:  9
# ['206595.p2', '191904.p2', '12445.p2', '33001.p2', '300273.p2', '266563.p2', '8775.p2', '13967.p2', '155208.p2', '281809.p2', '264454.p2', '349088.p2', '420884.p2', '73942.p2', '248887.p2', '4896.p2', '31001.p2', '422064.p2', '39304.p2', '20878.p2']
# ITERATION IN 0
# 264454. Max(delW):   0.000029	Max(delU):   0.000014
# 349088. 422064. Max(delW):   0.000030	Max(delU):   0.000002
# ITERATION IN 1
# 264454. Max(delW):   0.000028	Max(delU):   0.000014
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# ITERATION IN 2
# 264454. Max(delW):   0.000034	Max(delU):   0.000014
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# ITERATION IN 3
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# ITERATION IN 4
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# ITERATION IN 5
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# ITERATION IN 6
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# ITERATION IN 7
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# ITERATION IN 8
# 349088. 422064. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 9
# 349088. 422064. Max(delW):   0.000022	Max(delU):   0.000002
# Batch:  10
# ['27939.p2', '26954.p2', '163.p2', '134655.p2', '230014.p2', '104887.p2', '84456.p2', '117717.p2', '294655.p2', '320270.p2', '135793.p2', '32827.p2', '328961.p2', '198628.p2', '161846.p2', '408999.p2', '17463.p2', '9112.p2', '379990.p2', '72099.p2']
# ITERATION IN 0
# 134655. Max(delW):   0.000021	Max(delU):   0.000006
# 117717. Max(delW):   0.000048	Max(delU):   0.000004
# 320270. Max(delW):   0.000055	Max(delU):   0.000035
# 135793. Max(delW):   0.000022	Max(delU):   0.000003
# 198628. Max(delW):   0.000027	Max(delU):   0.000001
# ITERATION IN 1
# 117717. Max(delW):   0.000028	Max(delU):   0.000004
# 135793. Max(delW):   0.000022	Max(delU):   0.000003
# 198628. Max(delW):   0.000018	Max(delU):   0.000001
# ITERATION IN 2
# 117717. Max(delW):   0.000029	Max(delU):   0.000004
# 135793. Max(delW):   0.000022	Max(delU):   0.000003
# 198628. Max(delW):   0.000018	Max(delU):   0.000001
# ITERATION IN 3
# 117717. Max(delW):   0.000021	Max(delU):   0.000004
# 135793. Max(delW):   0.000022	Max(delU):   0.000003
# 198628. Max(delW):   0.000018	Max(delU):   0.000001
# ITERATION IN 4
# 117717. Max(delW):   0.000021	Max(delU):   0.000004
# 135793. Max(delW):   0.000024	Max(delU):   0.000003
# 198628. Max(delW):   0.000018	Max(delU):   0.000001
# ITERATION IN 5
# 117717. Max(delW):   0.000022	Max(delU):   0.000004
# 135793. Max(delW):   0.000024	Max(delU):   0.000003
# 198628. Max(delW):   0.000018	Max(delU):   0.000001
# ITERATION IN 6
# 117717. Max(delW):   0.000021	Max(delU):   0.000004
# 135793. Max(delW):   0.000034	Max(delU):   0.000005
# 198628. Max(delW):   0.000018	Max(delU):   0.000001
# ITERATION IN 7
# 117717. Max(delW):   0.000021	Max(delU):   0.000004
# 135793. Max(delW):   0.000034	Max(delU):   0.000005
# 198628. Max(delW):   0.000018	Max(delU):   0.000001
# ITERATION IN 8
# 117717. Max(delW):   0.000021	Max(delU):   0.000004
# 135793. Max(delW):   0.000034	Max(delU):   0.000005
# 198628. Max(delW):   0.000025	Max(delU):   0.000001
# ITERATION IN 9
# 117717. Max(delW):   0.000023	Max(delU):   0.000004
# 135793. Max(delW):   0.000034	Max(delU):   0.000005
# 198628. Max(delW):   0.000023	Max(delU):   0.000001
# Batch:  11
# ['122024.p2', '38604.p2', '390024.p2', '95726.p2', '39724.p2', '122876.p2', '6659.p2', '300717.p2', '41278.p2', '161000.p2', '287766.p2', '253607.p2', '238799.p2', '16404.p2', '581.p2', '32979.p2', '343820.p2', '14254.p2', '152944.p2', '414407.p2']
# ITERATION IN 0
# 390024. Max(delW):   0.000025	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000031	Max(delU):   0.000002
# ITERATION IN 1
# 390024. Max(delW):   0.000022	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000045	Max(delU):   0.000002
# ITERATION IN 2
# 390024. Max(delW):   0.000024	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000031	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 3
# 390024. Max(delW):   0.000039	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000018
# 287766. 343820. Max(delW):   0.000033	Max(delU):   0.000002
# ITERATION IN 4
# 390024. Max(delW):   0.000026	Max(delU):   0.000004
# 39724. Max(delW):   0.000045	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 5
# 390024. Max(delW):   0.000026	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000072	Max(delU):   0.000055
# ITERATION IN 6
# 390024. Max(delW):   0.000022	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000018
# 287766. 343820. Max(delW):   0.000034	Max(delU):   0.000002
# ITERATION IN 7
# 390024. Max(delW):   0.000025	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 8
# 390024. Max(delW):   0.000024	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 9
# 390024. Max(delW):   0.000025	Max(delU):   0.000004
# 39724. Max(delW):   0.000041	Max(delU):   0.000006
# 300717. Max(delW):   0.000027	Max(delU):   0.000019
# 287766. 343820. Max(delW):   0.000064	Max(delU):   0.000054
# Batch:  12
# ['350867.p2', '11577.p2', '30275.p2', '315881.p2', '41926.p2', '18010.p2', '25686.p2', '226301.p2', '437394.p2', '381969.p2', '406588.p2', '295148.p2', '403483.p2', '286123.p2', '7286.p2', '21248.p2', '135826.p2', '381600.p2', '378832.p2', '243101.p2']
# ITERATION IN 0
# 350867. 11577. Max(delW):   0.000027	Max(delU):   0.000004
# 315881. Max(delW):   0.000043	Max(delU):   0.000038
# 41926. Max(delW):   0.000034	Max(delU):   0.000016
# 437394. Max(delW):   0.000018	Max(delU):   0.000003
# ITERATION IN 1
# 350867. 11577. Max(delW):   0.000029	Max(delU):   0.000006
# 41926. Max(delW):   0.000032	Max(delU):   0.000017
# 437394. Max(delW):   0.000020	Max(delU):   0.000003
# ITERATION IN 2
# 350867. 11577. Max(delW):   0.000029	Max(delU):   0.000006
# 437394. Max(delW):   0.000018	Max(delU):   0.000003
# ITERATION IN 3
# 350867. 11577. Max(delW):   0.000022	Max(delU):   0.000005
# 437394. Max(delW):   0.000018	Max(delU):   0.000003
# ITERATION IN 4
# 350867. 11577. Max(delW):   0.000025	Max(delU):   0.000005
# 437394. Max(delW):   0.000020	Max(delU):   0.000003
# ITERATION IN 5
# 350867. 11577. Max(delW):   0.000022	Max(delU):   0.000005
# 437394. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 6
# 350867. 11577. Max(delW):   0.000022	Max(delU):   0.000006
# 437394. Max(delW):   0.000020	Max(delU):   0.000003
# ITERATION IN 7
# 350867. 11577. Max(delW):   0.000024	Max(delU):   0.000006
# 437394. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 8
# 350867. 11577. Max(delW):   0.000021	Max(delU):   0.000006
# 437394. Max(delW):   0.000020	Max(delU):   0.000003
# ITERATION IN 9
# 350867. 11577. Max(delW):   0.000021	Max(delU):   0.000006
# 437394. Max(delW):   0.000022	Max(delU):   0.000003
# Batch:  13
# ['159907.p2', '33996.p2', '428424.p2', '148188.p2', '278973.p2', '17525.p2', '35709.p2', '278589.p2', '314575.p2', '33749.p2', '340540.p2', '250642.p2', '270327.p2', '21123.p2', '107466.p2', '282504.p2', '150176.p2', '4508.p2', '16125.p2', '168982.p2']
# ITERATION IN 0
# 150176. Max(delW):   0.000028	Max(delU):   0.000005
# ITERATION IN 1
# 150176. Max(delW):   0.000027	Max(delU):   0.000005
# ITERATION IN 2
# 150176. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 3
# 150176. Max(delW):   0.000023	Max(delU):   0.000006
# ITERATION IN 4
# ITERATION IN 5
# ITERATION IN 6
# ITERATION IN 7
# ITERATION IN 8
# ITERATION IN 9
# Batch:  14
# ['95973.p2', '70323.p2', '4855.p2', '317584.p2', '356008.p2', '11899.p2', '391668.p2', '308760.p2', '148213.p2', '24058.p2', '417177.p2', '410092.p2', '45666.p2', '431466.p2', '152229.p2', '36022.p2', '139248.p2', '24897.p2', '314996.p2', '332745.p2']
# ITERATION IN 0
# 95973. Max(delW):   0.000027	Max(delU):   0.000009
# 317584. Max(delW):   0.000017	Max(delU):   0.000002
# 417177. Max(delW):   0.000049	Max(delU):   0.000004
# 431466. Max(delW):   0.000040	Max(delU):   0.000005
# ITERATION IN 1
# 95973. Max(delW):   0.000035	Max(delU):   0.000009
# 317584. Max(delW):   0.000015	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000027	Max(delU):   0.000005
# ITERATION IN 2
# 95973. Max(delW):   0.000035	Max(delU):   0.000009
# 317584. Max(delW):   0.000015	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000032	Max(delU):   0.000003
# ITERATION IN 3
# 95973. Max(delW):   0.000035	Max(delU):   0.000009
# 317584. Max(delW):   0.000017	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000021	Max(delU):   0.000003
# ITERATION IN 4
# 317584. Max(delW):   0.000017	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000026	Max(delU):   0.000003
# ITERATION IN 5
# 317584. Max(delW):   0.000016	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 6
# 317584. Max(delW):   0.000017	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 7
# 317584. Max(delW):   0.000016	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000026	Max(delU):   0.000003
# ITERATION IN 8
# 317584. Max(delW):   0.000017	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000026	Max(delU):   0.000003
# ITERATION IN 9
# 317584. Max(delW):   0.000017	Max(delU):   0.000002
# 417177. Max(delW):   0.000036	Max(delU):   0.000004
# 431466. Max(delW):   0.000022	Max(delU):   0.000003
# Batch:  15
# ['158670.p2', '250318.p2', '29600.p2', '30553.p2', '20137.p2', '7172.p2', '55890.p2', '84380.p2', '275162.p2', '388985.p2', '441479.p2', '18194.p2', '206966.p2', '42103.p2', '7611.p2', '313388.p2', '315728.p2', '310250.p2', '418399.p2', '105015.p2']
# ITERATION IN 0
# ITERATION IN 1
# ITERATION IN 2
# ITERATION IN 3
# ITERATION IN 4
# ITERATION IN 5
# ITERATION IN 6
# ITERATION IN 7
# ITERATION IN 8
# ITERATION IN 9
# Batch:  16
# ['30996.p2', '415470.p2', '6873.p2', '323581.p2', '163375.p2', '102862.p2', '373371.p2', '99737.p2', '389746.p2', '193340.p2', '16153.p2', '157133.p2', '262054.p2', '259912.p2', '161097.p2', '287194.p2', '217206.p2', '215684.p2', '330133.p2', '19635.p2']
# ITERATION IN 0
# 323581. Max(delW):   0.000029	Max(delU):   0.000006
# 193340. Max(delW):   0.000047	Max(delU):   0.000006
# 16153. Max(delW):   0.000052	Max(delU):   0.000022
# 287194. ITERATION IN 1
# 323581. Max(delW):   0.000029	Max(delU):   0.000005
# 193340. Max(delW):   0.000034	Max(delU):   0.000006
# 16153. Max(delW):   0.000052	Max(delU):   0.000021
# 287194. ITERATION IN 2
# 323581. Max(delW):   0.000031	Max(delU):   0.000005
# 193340. Max(delW):   0.000038	Max(delU):   0.000006
# 16153. Max(delW):   0.000052	Max(delU):   0.000020
# 287194. ITERATION IN 3
# 323581. Max(delW):   0.000041	Max(delU):   0.000006
# 193340. Max(delW):   0.000038	Max(delU):   0.000006
# 16153. Max(delW):   0.000056	Max(delU):   0.000020
# 287194. ITERATION IN 4
# 323581. Max(delW):   0.000041	Max(delU):   0.000006
# 193340. Max(delW):   0.000036	Max(delU):   0.000006
# 16153. Max(delW):   0.000052	Max(delU):   0.000019
# 287194. ITERATION IN 5
# 323581. Max(delW):   0.000041	Max(delU):   0.000006
# 16153. Max(delW):   0.000052	Max(delU):   0.000019
# 287194. ITERATION IN 6
# 323581. Max(delW):   0.000026	Max(delU):   0.000005
# 16153. Max(delW):   0.000052	Max(delU):   0.000018
# 287194. ITERATION IN 7
# 323581. Max(delW):   0.000027	Max(delU):   0.000004
# 16153. Max(delW):   0.000038	Max(delU):   0.000008
# 287194. ITERATION IN 8
# 323581. Max(delW):   0.000026	Max(delU):   0.000008
# 16153. Max(delW):   0.000052	Max(delU):   0.000018
# 287194. ITERATION IN 9
# 323581. Max(delW):   0.000022	Max(delU):   0.000004
# 16153. Max(delW):   0.000035	Max(delU):   0.000008
# 287194. Batch:  17
# ['232031.p2', '22688.p2', '2620.p2', '127696.p2', '8907.p2', '302226.p2', '38850.p2', '220261.p2', '421825.p2', '218758.p2', '329878.p2', '13597.p2', '261378.p2', '28689.p2', '43021.p2', '83776.p2', '213540.p2', '116007.p2', '43553.p2', '298145.p2']
# ITERATION IN 0
# 232031. Max(delW):   0.000019	Max(delU):   0.000004
# 421825. Max(delW):   0.000029	Max(delU):   0.000003
# 83776. Max(delW):   0.000029	Max(delU):   0.000003
# ITERATION IN 1
# 421825. Max(delW):   0.000024	Max(delU):   0.000003
# 83776. Max(delW):   0.000024	Max(delU):   0.000003
# ITERATION IN 2
# 421825. Max(delW):   0.000024	Max(delU):   0.000003
# 83776. Max(delW):   0.000024	Max(delU):   0.000003
# ITERATION IN 3
# 421825. Max(delW):   0.000024	Max(delU):   0.000003
# 83776. Max(delW):   0.000024	Max(delU):   0.000003
# ITERATION IN 4
# 421825. Max(delW):   0.000024	Max(delU):   0.000003
# 83776. Max(delW):   0.000024	Max(delU):   0.000003
# ITERATION IN 5
# 421825. Max(delW):   0.000024	Max(delU):   0.000003
# 83776. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 6
# 421825. Max(delW):   0.000024	Max(delU):   0.000002
# 83776. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 7
# 421825. Max(delW):   0.000024	Max(delU):   0.000002
# 83776. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 8
# 421825. Max(delW):   0.000024	Max(delU):   0.000002
# 83776. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 9
# 421825. Max(delW):   0.000024	Max(delU):   0.000002
# 83776. Max(delW):   0.000024	Max(delU):   0.000002
# Batch:  18
# ['13056.p2', '82553.p2', '141703.p2', '345828.p2', '425080.p2', '242894.p2', '9756.p2', '32167.p2', '273125.p2', '26252.p2', '224837.p2', '164014.p2', '16977.p2', '317262.p2', '4660.p2', '139068.p2', '401219.p2', '399856.p2', '25751.p2', '253575.p2']
# ITERATION IN 0
# 82553. Max(delW):   0.000024	Max(delU):   0.000002
# 9756. Max(delW):   0.000022	Max(delU):   0.000005
# ITERATION IN 1
# 82553. Max(delW):   0.000024	Max(delU):   0.000002
# 9756. Max(delW):   0.000020	Max(delU):   0.000005
# ITERATION IN 2
# 82553. Max(delW):   0.000024	Max(delU):   0.000002
# 9756. Max(delW):   0.000024	Max(delU):   0.000005
# ITERATION IN 3
# 82553. Max(delW):   0.000024	Max(delU):   0.000002
# 9756. Max(delW):   0.000030	Max(delU):   0.000005
# ITERATION IN 4
# 82553. Max(delW):   0.000024	Max(delU):   0.000002
# 9756. Max(delW):   0.000021	Max(delU):   0.000005
# ITERATION IN 5
# 82553. Max(delW):   0.000028	Max(delU):   0.000002
# 9756. Max(delW):   0.000029	Max(delU):   0.000005
# ITERATION IN 6
# 82553. Max(delW):   0.000029	Max(delU):   0.000002
# 9756. Max(delW):   0.000024	Max(delU):   0.000005
# ITERATION IN 7
# 82553. Max(delW):   0.000029	Max(delU):   0.000002
# 9756. Max(delW):   0.000022	Max(delU):   0.000005
# ITERATION IN 8
# 82553. Max(delW):   0.000030	Max(delU):   0.000002
# 9756. Max(delW):   0.000030	Max(delU):   0.000005
# ITERATION IN 9
# 82553. Max(delW):   0.000029	Max(delU):   0.000002
# 9756. Max(delW):   0.000022	Max(delU):   0.000005
# Batch:  19
# ['77533.p2', '284586.p2', '28515.p2', '180379.p2', '130437.p2', '68780.p2', '387842.p2', '242022.p2', '295600.p2', '298219.p2', '164056.p2', '384597.p2', '292934.p2', '61559.p2', '214523.p2', '334516.p2', '2379.p2', '68412.p2', '98573.p2', '303862.p2']
# ITERATION IN 0
# 284586. Max(delW):   0.000004	Max(delU):   0.000000
# 303862. Max(delW):   0.000035	Max(delU):   0.000006
# ITERATION IN 1
# 284586. Max(delW):   0.000004	Max(delU):   0.000000
# 303862. Max(delW):   0.000036	Max(delU):   0.000006
# ITERATION IN 2
# 284586. Max(delW):   0.000004	Max(delU):   0.000000
# 303862. Max(delW):   0.000031	Max(delU):   0.000006
# ITERATION IN 3
# 284586. Max(delW):   0.000004	Max(delU):   0.000001
# 303862. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 4
# 284586. Max(delW):   0.000004	Max(delU):   0.000001
# 303862. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 5
# 284586. Max(delW):   0.000004	Max(delU):   0.000001
# 303862. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 6
# 284586. Max(delW):   0.000004	Max(delU):   0.000001
# 303862. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 7
# 284586. Max(delW):   0.000004	Max(delU):   0.000001
# 303862. Max(delW):   0.000014	Max(delU):   0.000002
# ITERATION IN 8
# 284586. Max(delW):   0.000004	Max(delU):   0.000001
# 303862. Max(delW):   0.000014	Max(delU):   0.000002
# ITERATION IN 9
# 284586. Max(delW):   0.000004	Max(delU):   0.000001
# 303862. Max(delW):   0.000014	Max(delU):   0.000002
# Batch:  20
# ['43889.p2', '42963.p2', '37887.p2', '343232.p2', '417994.p2', '381911.p2', '401005.p2', '279033.p2', '45650.p2', '260022.p2', '254574.p2', '18955.p2', '7421.p2', '12236.p2', '287041.p2', '156448.p2', '6519.p2', '253861.p2', '150617.p2', '93086.p2']
# ITERATION IN 0
# 279033. Max(delW):   0.000025	Max(delU):   0.000002
# 260022. Max(delW):   0.000027	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000036	Max(delU):   0.000007
# 150617. ITERATION IN 1
# 279033. Max(delW):   0.000049	Max(delU):   0.000002
# 260022. Max(delW):   0.000023	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000030	Max(delU):   0.000007
# 150617. ITERATION IN 2
# 279033. Max(delW):   0.000024	Max(delU):   0.000002
# 260022. Max(delW):   0.000023	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000030	Max(delU):   0.000006
# 150617. ITERATION IN 3
# 279033. Max(delW):   0.000029	Max(delU):   0.000002
# 260022. Max(delW):   0.000023	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000029	Max(delU):   0.000006
# 150617. ITERATION IN 4
# 279033. Max(delW):   0.000024	Max(delU):   0.000002
# 260022. Max(delW):   0.000029	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000029	Max(delU):   0.000006
# 150617. ITERATION IN 5
# 279033. Max(delW):   0.000024	Max(delU):   0.000002
# 260022. Max(delW):   0.000023	Max(delU):   0.000006
# 287041. 253861. Max(delW):   0.000029	Max(delU):   0.000006
# 150617. ITERATION IN 6
# 279033. 260022. Max(delW):   0.000023	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000029	Max(delU):   0.000006
# 150617. ITERATION IN 7
# 279033. 260022. Max(delW):   0.000029	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000029	Max(delU):   0.000006
# 150617. ITERATION IN 8
# 279033. 260022. Max(delW):   0.000030	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000029	Max(delU):   0.000006
# 150617. ITERATION IN 9
# 279033. 260022. Max(delW):   0.000023	Max(delU):   0.000005
# 287041. 253861. Max(delW):   0.000029	Max(delU):   0.000006
# 150617. Batch:  21
# ['255561.p2', '438554.p2', '7387.p2', '27668.p2', '408922.p2', '3789.p2', '101007.p2', '421874.p2', '390332.p2', '286810.p2', '20319.p2', '5046.p2', '99100.p2', '428908.p2', '18336.p2', '82788.p2', '109051.p2', '35740.p2', '34299.p2', '41287.p2']
# ITERATION IN 0
# 101007. Max(delW):   0.000018	Max(delU):   0.000002
# 390332. Max(delW):   0.000049	Max(delU):   0.000018
# 286810. 82788. Max(delW):   0.000045	Max(delU):   0.000007
# ITERATION IN 1
# 101007. Max(delW):   0.000018	Max(delU):   0.000002
# 390332. Max(delW):   0.000049	Max(delU):   0.000018
# 286810. 82788. Max(delW):   0.000050	Max(delU):   0.000007
# ITERATION IN 2
# 101007. Max(delW):   0.000023	Max(delU):   0.000003
# 390332. Max(delW):   0.000053	Max(delU):   0.000018
# 286810. 82788. Max(delW):   0.000050	Max(delU):   0.000007
# ITERATION IN 3
# 101007. Max(delW):   0.000021	Max(delU):   0.000004
# 390332. Max(delW):   0.000053	Max(delU):   0.000019
# 286810. 82788. Max(delW):   0.000053	Max(delU):   0.000007
# ITERATION IN 4
# 101007. Max(delW):   0.000023	Max(delU):   0.000004
# 390332. Max(delW):   0.000053	Max(delU):   0.000019
# 286810. 82788. Max(delW):   0.000050	Max(delU):   0.000007
# ITERATION IN 5
# 101007. Max(delW):   0.000023	Max(delU):   0.000005
# 390332. Max(delW):   0.000053	Max(delU):   0.000019
# 286810. 82788. Max(delW):   0.000050	Max(delU):   0.000007
# ITERATION IN 6
# 101007. Max(delW):   0.000023	Max(delU):   0.000003
# 390332. Max(delW):   0.000049	Max(delU):   0.000019
# 286810. 82788. Max(delW):   0.000050	Max(delU):   0.000007
# ITERATION IN 7
# 101007. Max(delW):   0.000025	Max(delU):   0.000005
# 286810. 82788. Max(delW):   0.000050	Max(delU):   0.000007
# ITERATION IN 8
# 101007. Max(delW):   0.000023	Max(delU):   0.000005
# 286810. 82788. Max(delW):   0.000045	Max(delU):   0.000008
# ITERATION IN 9
# 101007. Max(delW):   0.000023	Max(delU):   0.000005
# 286810. 82788. Batch:  22
# ['329360.p2', '348906.p2', '216967.p2', '91951.p2', '19401.p2', '156428.p2', '35527.p2', '164684.p2', '149391.p2', '124562.p2', '320870.p2', '432920.p2', '143348.p2', '17114.p2', '87243.p2', '29933.p2', '292158.p2', '247832.p2', '44437.p2', '147458.p2']
# ITERATION IN 0
# 143348. 292158. Max(delW):   0.000051	Max(delU):   0.000007
# ITERATION IN 1
# 143348. 292158. Max(delW):   0.000051	Max(delU):   0.000007
# ITERATION IN 2
# 143348. 292158. Max(delW):   0.000051	Max(delU):   0.000007
# ITERATION IN 3
# 143348. ITERATION IN 4
# 143348. ITERATION IN 5
# 143348. ITERATION IN 6
# 143348. ITERATION IN 7
# 143348. ITERATION IN 8
# 143348. ITERATION IN 9
# 143348. Batch:  23
# ['416082.p2', '297875.p2', '59557.p2', '102970.p2', '30350.p2', '63441.p2', '392372.p2', '41543.p2', '15690.p2', '25082.p2', '72698.p2', '270812.p2', '35260.p2', '90592.p2', '46231.p2', '142737.p2', '211745.p2', '8222.p2', '392725.p2', '38461.p2']
# ITERATION IN 0
# 15690. Max(delW):   0.000053	Max(delU):   0.000018
# 38461. ITERATION IN 1
# 15690. Max(delW):   0.000050	Max(delU):   0.000018
# 38461. ITERATION IN 2
# 38461. ITERATION IN 3
# 38461. ITERATION IN 4
# 38461. ITERATION IN 5
# 38461. ITERATION IN 6
# 38461. ITERATION IN 7
# 38461. ITERATION IN 8
# 38461. ITERATION IN 9
# 38461. Batch:  24
# ['80320.p2', '5192.p2', '12415.p2', '34399.p2', '37444.p2', '11657.p2', '262303.p2', '434417.p2', '16631.p2', '274890.p2', '113610.p2', '4939.p2', '22150.p2', '138286.p2', '107682.p2', '171061.p2', '337653.p2', '85512.p2', '18445.p2', '87323.p2']
# ITERATION IN 0
# 80320. Max(delW):   0.000032	Max(delU):   0.000013
# 37444. Max(delW):   0.000028	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000050	Max(delU):   0.000014
# 87323. Max(delW):   0.000029	Max(delU):   0.000004
# ITERATION IN 1
# 80320. Max(delW):   0.000036	Max(delU):   0.000013
# 37444. Max(delW):   0.000036	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000050	Max(delU):   0.000014
# 87323. Max(delW):   0.000046	Max(delU):   0.000004
# ITERATION IN 2
# 80320. Max(delW):   0.000030	Max(delU):   0.000013
# 37444. Max(delW):   0.000028	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000046	Max(delU):   0.000012
# 87323. Max(delW):   0.000041	Max(delU):   0.000004
# ITERATION IN 3
# 37444. Max(delW):   0.000042	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000046	Max(delU):   0.000012
# 87323. Max(delW):   0.000024	Max(delU):   0.000005
# ITERATION IN 4
# 37444. Max(delW):   0.000051	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000055	Max(delU):   0.000012
# 87323. Max(delW):   0.000024	Max(delU):   0.000005
# ITERATION IN 5
# 37444. Max(delW):   0.000031	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000044	Max(delU):   0.000015
# 87323. Max(delW):   0.000031	Max(delU):   0.000005
# ITERATION IN 6
# 37444. Max(delW):   0.000044	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000054	Max(delU):   0.000012
# 87323. Max(delW):   0.000054	Max(delU):   0.000005
# ITERATION IN 7
# 37444. Max(delW):   0.000029	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000055	Max(delU):   0.000012
# 87323. Max(delW):   0.000051	Max(delU):   0.000005
# ITERATION IN 8
# 37444. Max(delW):   0.000029	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000057	Max(delU):   0.000013
# 87323. Max(delW):   0.000038	Max(delU):   0.000005
# ITERATION IN 9
# 37444. Max(delW):   0.000029	Max(delU):   0.000001
# 274890. 4939. Max(delW):   0.000052	Max(delU):   0.000013
# 87323. Max(delW):   0.000029	Max(delU):   0.000005
# Batch:  25
# ['16215.p2', '22574.p2', '176853.p2', '60755.p2', '215825.p2', '378389.p2', '434151.p2', '155044.p2', '27226.p2', '2327.p2', '343387.p2', '234671.p2', '152844.p2', '171533.p2', '15137.p2', '20530.p2', '374366.p2', '125691.p2', '92199.p2', '168176.p2']
# ITERATION IN 0
# 20530. 92199. Max(delW):   0.000028	Max(delU):   0.000005
# ITERATION IN 1
# 20530. 92199. Max(delW):   0.000021	Max(delU):   0.000005
# ITERATION IN 2
# 20530. 92199. Max(delW):   0.000020	Max(delU):   0.000005
# ITERATION IN 3
# 20530. 92199. Max(delW):   0.000017	Max(delU):   0.000005
# ITERATION IN 4
# 20530. 92199. Max(delW):   0.000025	Max(delU):   0.000005
# ITERATION IN 5
# 20530. 92199. Max(delW):   0.000016	Max(delU):   0.000003
# ITERATION IN 6
# 20530. 92199. Max(delW):   0.000033	Max(delU):   0.000005
# ITERATION IN 7
# 20530. 92199. Max(delW):   0.000016	Max(delU):   0.000003
# ITERATION IN 8
# 20530. 92199. Max(delW):   0.000018	Max(delU):   0.000002
# ITERATION IN 9
# 20530. 92199. Max(delW):   0.000013	Max(delU):   0.000002
# Batch:  26
# ['433932.p2', '163424.p2', '223537.p2', '31866.p2', '240505.p2', '356551.p2', '324429.p2', '64898.p2', '8256.p2', '41214.p2', '409843.p2', '367744.p2', '323233.p2', '131250.p2', '399994.p2', '366544.p2', '291636.p2', '231234.p2', '107668.p2', '57621.p2']
# ITERATION IN 0
# 163424. Max(delW):   0.000022	Max(delU):   0.000004
# 366544. Max(delW):   0.000046	Max(delU):   0.000018
# ITERATION IN 1
# 163424. Max(delW):   0.000028	Max(delU):   0.000004
# 366544. Max(delW):   0.000033	Max(delU):   0.000014
# ITERATION IN 2
# 163424. Max(delW):   0.000023	Max(delU):   0.000004
# 366544. Max(delW):   0.000035	Max(delU):   0.000014
# ITERATION IN 3
# 163424. Max(delW):   0.000028	Max(delU):   0.000005
# 366544. Max(delW):   0.000036	Max(delU):   0.000019
# ITERATION IN 4
# 163424. Max(delW):   0.000024	Max(delU):   0.000004
# 366544. Max(delW):   0.000036	Max(delU):   0.000019
# ITERATION IN 5
# 163424. Max(delW):   0.000030	Max(delU):   0.000005
# ITERATION IN 6
# 163424. Max(delW):   0.000037	Max(delU):   0.000005
# ITERATION IN 7
# 163424. Max(delW):   0.000023	Max(delU):   0.000004
# ITERATION IN 8
# 163424. Max(delW):   0.000023	Max(delU):   0.000004
# ITERATION IN 9
# 163424. Max(delW):   0.000028	Max(delU):   0.000005
# Batch:  27
# ['29037.p2', '12312.p2', '6592.p2', '427820.p2', '115062.p2', '303448.p2', '73257.p2', '168283.p2', '131757.p2', '38457.p2', '34290.p2', '153306.p2', '200657.p2', '106747.p2', '27499.p2', '323940.p2', '37307.p2', '285276.p2', '34834.p2', '365301.p2']
# ITERATION IN 0
# 12312. Max(delW):   0.000020	Max(delU):   0.000004
# ITERATION IN 1
# 12312. Max(delW):   0.000016	Max(delU):   0.000004
# ITERATION IN 2
# 12312. Max(delW):   0.000019	Max(delU):   0.000004
# ITERATION IN 3
# 12312. Max(delW):   0.000022	Max(delU):   0.000004
# ITERATION IN 4
# 12312. Max(delW):   0.000031	Max(delU):   0.000005
# ITERATION IN 5
# 12312. Max(delW):   0.000024	Max(delU):   0.000005
# ITERATION IN 6
# 12312. Max(delW):   0.000028	Max(delU):   0.000005
# ITERATION IN 7
# 12312. Max(delW):   0.000024	Max(delU):   0.000005
# ITERATION IN 8
# 12312. Max(delW):   0.000030	Max(delU):   0.000006
# ITERATION IN 9
# 12312. Max(delW):   0.000018	Max(delU):   0.000004
# Batch:  28
# ['66890.p2', '355407.p2', '385081.p2', '45392.p2', '5819.p2', '11641.p2', '182077.p2', '430973.p2', '371747.p2', '158836.p2', '84313.p2', '387792.p2', '2539.p2', '312729.p2', '44520.p2', '148456.p2', '11374.p2', '279017.p2', '314811.p2', '432223.p2']
# ITERATION IN 0
# 355407. 182077. Max(delW):   0.000041	Max(delU):   0.000019
# 158836. 84313. Max(delW):   0.000028	Max(delU):   0.000002
# ITERATION IN 1
# 355407. 182077. Max(delW):   0.000032	Max(delU):   0.000019
# 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 2
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 3
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 4
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 5
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 6
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 7
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 8
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# ITERATION IN 9
# 355407. 158836. 84313. Max(delW):   0.000024	Max(delU):   0.000002
# Batch:  29
# ['216398.p2', '244454.p2', '149755.p2', '29894.p2', '66442.p2', '61911.p2', '45735.p2', '11589.p2', '9076.p2', '131098.p2', '28786.p2', '87617.p2', '279689.p2', '227474.p2', '410732.p2', '324206.p2', '11052.p2', '279050.p2', '252846.p2', '18763.p2']
# ITERATION IN 0
# 216398. Max(delW):   0.000022	Max(delU):   0.000003
# 410732. Max(delW):   0.000037	Max(delU):   0.000006
# ITERATION IN 1
# 216398. Max(delW):   0.000015	Max(delU):   0.000002
# 410732. Max(delW):   0.000029	Max(delU):   0.000006
# ITERATION IN 2
# 216398. Max(delW):   0.000016	Max(delU):   0.000003
# 410732. Max(delW):   0.000035	Max(delU):   0.000006
# ITERATION IN 3
# 216398. Max(delW):   0.000016	Max(delU):   0.000002
# 410732. Max(delW):   0.000035	Max(delU):   0.000006
# ITERATION IN 4
# 216398. Max(delW):   0.000016	Max(delU):   0.000002
# 410732. Max(delW):   0.000035	Max(delU):   0.000006
# ITERATION IN 5
# 216398. Max(delW):   0.000015	Max(delU):   0.000002
# 410732. Max(delW):   0.000035	Max(delU):   0.000006
# ITERATION IN 6
# 216398. Max(delW):   0.000015	Max(delU):   0.000002
# 410732. Max(delW):   0.000035	Max(delU):   0.000006
# ITERATION IN 7
# 216398. Max(delW):   0.000015	Max(delU):   0.000002
# 410732. Max(delW):   0.000044	Max(delU):   0.000006
# ITERATION IN 8
# 216398. Max(delW):   0.000016	Max(delU):   0.000002
# 410732. Max(delW):   0.000044	Max(delU):   0.000006
# ITERATION IN 9
# 216398. Max(delW):   0.000015	Max(delU):   0.000002
# 410732. Max(delW):   0.000044	Max(delU):   0.000006
# Batch:  30
# ['69952.p2', '242803.p2', '10644.p2', '1093.p2', '261313.p2', '378501.p2', '42257.p2', '5330.p2', '174983.p2', '419187.p2', '366040.p2', '176361.p2', '306417.p2', '27798.p2', '9381.p2', '293575.p2', '7736.p2', '130731.p2', '416428.p2', '16130.p2']
# ITERATION IN 0
# 10644. Max(delW):   0.000034	Max(delU):   0.000008
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# ITERATION IN 1
# 10644. Max(delW):   0.000034	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# ITERATION IN 2
# 10644. Max(delW):   0.000029	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# ITERATION IN 3
# 10644. Max(delW):   0.000026	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# ITERATION IN 4
# 10644. Max(delW):   0.000029	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# ITERATION IN 5
# 10644. Max(delW):   0.000029	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# ITERATION IN 6
# 10644. Max(delW):   0.000026	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# ITERATION IN 7
# 10644. Max(delW):   0.000029	Max(delU):   0.000007
# 5330. Max(delW):   0.000035	Max(delU):   0.000007
# ITERATION IN 8
# 10644. Max(delW):   0.000026	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000008
# ITERATION IN 9
# 10644. Max(delW):   0.000029	Max(delU):   0.000007
# 5330. Max(delW):   0.000032	Max(delU):   0.000007
# Batch:  31
# ['141064.p2', '177571.p2', '429859.p2', '377744.p2', '299988.p2', '3342.p2', '118494.p2', '297732.p2', '266984.p2', '196012.p2', '87848.p2', '176735.p2', '26322.p2', '278804.p2', '205511.p2', '342857.p2', '152212.p2', '287679.p2', '279654.p2', '280310.p2']
# ITERATION IN 0
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 266984. Max(delW):   0.000035	Max(delU):   0.000007
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 1
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 266984. Max(delW):   0.000027	Max(delU):   0.000007
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 2
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 266984. Max(delW):   0.000026	Max(delU):   0.000007
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 3
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 266984. Max(delW):   0.000026	Max(delU):   0.000007
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 4
# 141064. Max(delW):   0.000037	Max(delU):   0.000005
# 266984. Max(delW):   0.000026	Max(delU):   0.000008
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 5
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 266984. Max(delW):   0.000026	Max(delU):   0.000008
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 6
# 141064. Max(delW):   0.000038	Max(delU):   0.000005
# 266984. Max(delW):   0.000026	Max(delU):   0.000008
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 7
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 266984. Max(delW):   0.000026	Max(delU):   0.000008
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 8
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. ITERATION IN 9
# 141064. Max(delW):   0.000024	Max(delU):   0.000005
# 278804. Max(delW):   0.000000	Max(delU):   0.000000
# 287679. Batch:  32
# ['248619.p2', '318915.p2', '356243.p2', '22315.p2', '384.p2', '231541.p2', '6453.p2', '345.p2', '138195.p2', '30265.p2', '173598.p2', '412629.p2', '22049.p2', '83711.p2', '35367.p2', '357385.p2', '367270.p2', '388456.p2', '119638.p2', '45834.p2']
# ITERATION IN 0
# 356243. Max(delW):   0.000006	Max(delU):   0.000001
# 173598. 22049. 83711. 357385. Max(delW):   0.000027	Max(delU):   0.000004
# ITERATION IN 1
# 356243. Max(delW):   0.000005	Max(delU):   0.000001
# ...
# ITERATION IN 4
# 54286. Max(delW):   0.000027	Max(delU):   0.000001
# 266983. Max(delW):   0.000021	Max(delU):   0.000003
# 208044. Max(delW):   0.000023	Max(delU):   0.000006
# ITERATION IN 5
# 54286. Max(delW):   0.000021	Max(delU):   0.000001
# 266983. Max(delW):   0.000021	Max(delU):   0.000003
# 208044. Max(delW):   0.000022	Max(delU):   0.000006
# ITERATION IN 6
# 54286. Max(delW):   0.000021	Max(delU):   0.000001
# 266983. Max(delW):   0.000021	Max(delU):   0.000003
# 208044. Max(delW):   0.000022	Max(delU):   0.000006
# ITERATION IN 7
# 54286. Max(delW):   0.000021	Max(delU):   0.000001
# 266983. Max(delW):   0.000021	Max(delU):   0.000003
# 208044. Max(delW):   0.000021	Max(delU):   0.000006
# ITERATION IN 8
# 54286. Max(delW):   0.000021	Max(delU):   0.000001
# 266983. Max(delW):   0.000021	Max(delU):   0.000003
# 208044. Max(delW):   0.000022	Max(delU):   0.000006
# ITERATION IN 9
# 54286. Max(delW):   0.000021	Max(delU):   0.000001
# 266983. Max(delW):   0.000021	Max(delU):   0.000003
# 208044. Max(delW):   0.000020	Max(delU):   0.000006
# Batch:  98
# ['28345.p2', '427053.p2', '386463.p2', '249762.p2', '34113.p2', '50575.p2', '437538.p2', '416852.p2', '15539.p2', '83729.p2', '76323.p2', '404532.p2', '398070.p2', '253175.p2', '8671.p2', '75695.p2', '17026.p2', '308389.p2', '7573.p2', '99489.p2']
# ITERATION IN 0
# 416852. Max(delW):   0.000031	Max(delU):   0.000005
# ITERATION IN 1
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 2
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 3
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 4
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 5
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 6
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 7
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 8
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# ITERATION IN 9
# 416852. Max(delW):   0.000023	Max(delU):   0.000005
# Batch:  99
# ['41154.p2', '433738.p2', '690.p2', '32573.p2', '20976.p2', '428990.p2', '245025.p2', '104589.p2', '21444.p2', '27860.p2', '35686.p2', '130438.p2', '309009.p2', '163578.p2', '185646.p2', '153383.p2', '419463.p2', '339108.p2', '77578.p2', '160481.p2']
# ITERATION IN 0
# 32573. 245025. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 1
# 32573. 245025. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 2
# 32573. 245025. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 3
# 32573. 245025. Max(delW):   0.000017	Max(delU):   0.000002
# ITERATION IN 4
# 32573. 245025. Max(delW):   0.000015	Max(delU):   0.000002
# ITERATION IN 5
# 32573. 245025. Max(delW):   0.000015	Max(delU):   0.000002
# ITERATION IN 6
# 32573. 245025. Max(delW):   0.000015	Max(delU):   0.000002
# ITERATION IN 7
# 32573. 245025. Max(delW):   0.000015	Max(delU):   0.000002
# ITERATION IN 8
# 32573. 245025. Max(delW):   0.000015	Max(delU):   0.000002
# ITERATION IN 9
# 32573. 245025. Max(delW):   0.000015	Max(delU):   0.000002
# Batch:  100
# ['252313.p2', '318289.p2', '268352.p2', '55779.p2', '228689.p2', '401567.p2', '394929.p2', '357948.p2', '10250.p2', '82324.p2', '41224.p2', '82547.p2', '43614.p2', '205834.p2', '352100.p2', '259325.p2', '4013.p2', '8756.p2', '377064.p2', '11933.p2']
# ITERATION IN 0
# 55779. Max(delW):   0.000033	Max(delU):   0.000006
# 82547. Max(delW):   0.000053	Max(delU):   0.000008
# ITERATION IN 1
# 55779. Max(delW):   0.000039	Max(delU):   0.000006
# 82547. Max(delW):   0.000051	Max(delU):   0.000008
# ITERATION IN 2
# 55779. Max(delW):   0.000033	Max(delU):   0.000005
# 82547. Max(delW):   0.000049	Max(delU):   0.000008
# ITERATION IN 3
# 55779. Max(delW):   0.000033	Max(delU):   0.000005
# 82547. Max(delW):   0.000045	Max(delU):   0.000008
# ITERATION IN 4
# 55779. Max(delW):   0.000033	Max(delU):   0.000005
# 82547. Max(delW):   0.000049	Max(delU):   0.000008
# ITERATION IN 5
# 55779. Max(delW):   0.000033	Max(delU):   0.000005
# 82547. Max(delW):   0.000045	Max(delU):   0.000007
# ITERATION IN 6
# 55779. Max(delW):   0.000033	Max(delU):   0.000005
# 82547. Max(delW):   0.000049	Max(delU):   0.000007
# ITERATION IN 7
# 55779. Max(delW):   0.000033	Max(delU):   0.000005
# 82547. Max(delW):   0.000045	Max(delU):   0.000007
# ITERATION IN 8
# 55779. Max(delW):   0.000033	Max(delU):   0.000005
# 82547. Max(delW):   0.000049	Max(delU):   0.000007
# ITERATION IN 9
# 55779. Max(delW):   0.000039	Max(delU):   0.000006
# 82547. Max(delW):   0.000045	Max(delU):   0.000008
# Batch:  101
# ['3328.p2', '19858.p2', '43790.p2', '263198.p2', '214128.p2', '37691.p2', '281068.p2', '33162.p2', '35559.p2', '79471.p2', '295413.p2', '268600.p2', '42675.p2', '157029.p2', '368040.p2', '149054.p2', '405046.p2', '136540.p2', '18155.p2', '34419.p2']
# ITERATION IN 0
# 295413. Max(delW):   0.000030	Max(delU):   0.000002
# 268600. Max(delW):   0.000030	Max(delU):   0.000006
# ITERATION IN 1
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# 268600. Max(delW):   0.000030	Max(delU):   0.000006
# ITERATION IN 2
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 3
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 4
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 5
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 6
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 7
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 8
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# ITERATION IN 9
# 295413. Max(delW):   0.000027	Max(delU):   0.000002
# Batch:  102
# ['30960.p2', '399030.p2', '147118.p2', '218672.p2', '36248.p2', '40657.p2', '439574.p2', '249904.p2', '306119.p2', '342749.p2', '320445.p2', '110852.p2', '11847.p2', '20261.p2', '46124.p2', '96897.p2', '287896.p2', '389984.p2', '26043.p2', '29.p2']
# ITERATION IN 0
# 30960. Max(delW):   0.000048	Max(delU):   0.000005
# 26043. Max(delW):   0.000023	Max(delU):   0.000003
# ITERATION IN 1
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000023	Max(delU):   0.000003
# ITERATION IN 2
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000032	Max(delU):   0.000003
# ITERATION IN 3
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000032	Max(delU):   0.000003
# ITERATION IN 4
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000032	Max(delU):   0.000003
# ITERATION IN 5
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000032	Max(delU):   0.000003
# ITERATION IN 6
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000032	Max(delU):   0.000003
# ITERATION IN 7
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000032	Max(delU):   0.000003
# ITERATION IN 8
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000023	Max(delU):   0.000003
# ITERATION IN 9
# 30960. Max(delW):   0.000043	Max(delU):   0.000005
# 26043. Max(delW):   0.000023	Max(delU):   0.000003
# Batch:  103
# ['325286.p2', '26551.p2', '170882.p2', '76076.p2', '36708.p2', '80235.p2', '76314.p2', '36843.p2', '11189.p2', '231919.p2', '46085.p2', '424563.p2', '232567.p2', '324754.p2', '160008.p2', '339385.p2', '367681.p2', '42273.p2', '354209.p2', '65353.p2']
# ITERATION IN 0
# 76076. 36843. Max(delW):   0.000034	Max(delU):   0.000006
# 11189. Max(delW):   0.000016	Max(delU):   0.000010
# 231919. Max(delW):   0.000046	Max(delU):   0.000012
# 424563. Max(delW):   0.000016	Max(delU):   0.000001
# 232567. ITERATION IN 1
# 76076. 36843. Max(delW):   0.000033	Max(delU):   0.000006
# 11189. Max(delW):   0.000016	Max(delU):   0.000010
# 231919. Max(delW):   0.000046	Max(delU):   0.000012
# 424563. Max(delW):   0.000018	Max(delU):   0.000001
# 232567. ITERATION IN 2
# 76076. 36843. Max(delW):   0.000033	Max(delU):   0.000006
# 11189. Max(delW):   0.000016	Max(delU):   0.000010
# 231919. Max(delW):   0.000046	Max(delU):   0.000012
# 424563. Max(delW):   0.000024	Max(delU):   0.000002
# 232567. ITERATION IN 3
# 76076. 36843. Max(delW):   0.000033	Max(delU):   0.000006
# 11189. Max(delW):   0.000016	Max(delU):   0.000010
# 231919. Max(delW):   0.000046	Max(delU):   0.000012
# 424563. Max(delW):   0.000019	Max(delU):   0.000002
# 232567. ITERATION IN 4
# 76076. 36843. Max(delW):   0.000033	Max(delU):   0.000006
# 11189. Max(delW):   0.000020	Max(delU):   0.000010
# 231919. Max(delW):   0.000046	Max(delU):   0.000012
# 232567. ITERATION IN 5
# 76076. 36843. Max(delW):   0.000033	Max(delU):   0.000006
# 11189. Max(delW):   0.000016	Max(delU):   0.000010
# 231919. Max(delW):   0.000046	Max(delU):   0.000013
# 232567. ITERATION IN 6
# 76076. 36843. Max(delW):   0.000033	Max(delU):   0.000006
# 11189. Max(delW):   0.000019	Max(delU):   0.000010
# 231919. Max(delW):   0.000046	Max(delU):   0.000013
# 232567. ITERATION IN 7
# 76076. 11189. Max(delW):   0.000019	Max(delU):   0.000010
# 232567. ITERATION IN 8
# 76076. 11189. Max(delW):   0.000016	Max(delU):   0.000010
# 232567. ITERATION IN 9
# 76076. 11189. Max(delW):   0.000016	Max(delU):   0.000009
# 232567. Batch:  104
# ['2424.p2', '365170.p2', '10998.p2', '33946.p2', '141013.p2', '64295.p2', '418469.p2', '287070.p2', '321625.p2', '338396.p2', '369933.p2', '5212.p2', '231943.p2', '18736.p2', '22602.p2', '4442.p2', '110065.p2', '440095.p2', '125172.p2', '112506.p2']
# ITERATION IN 0
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000028
# 440095. ITERATION IN 1
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000027
# 440095. ITERATION IN 2
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000026
# 440095. ITERATION IN 3
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000025
# 440095. ITERATION IN 4
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000025
# 440095. Max(delW):   0.000126	Max(delU):   0.000115
# ITERATION IN 5
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000027
# 440095. ITERATION IN 6
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000027
# 440095. ITERATION IN 7
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000026
# 440095. ITERATION IN 8
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000025
# 440095. ITERATION IN 9
# 287070. 18736. Max(delW):   0.000025	Max(delU):   0.000025
# 440095. Max(delW):   0.000126	Max(delU):   0.000118
# Batch:  105
# ['316779.p2', '377978.p2', '385938.p2', '158357.p2', '183987.p2', '25535.p2', '144545.p2', '206703.p2', '342743.p2', '318620.p2', '161938.p2', '434260.p2', '100347.p2', '9530.p2', '318961.p2', '8767.p2', '140148.p2', '74150.p2', '17084.p2', '147054.p2']
# ITERATION IN 0
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 1
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 2
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 3
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 4
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 5
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 6
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 7
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 8
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# ITERATION IN 9
# 147054. Max(delW):   0.000022	Max(delU):   0.000003
# Batch:  106
# ['50646.p2', '216874.p2', '323023.p2', '17216.p2', '180354.p2', '2178.p2', '4159.p2', '215081.p2', '141606.p2', '425273.p2', '109357.p2', '277546.p2', '249110.p2', '247517.p2', '319627.p2', '41748.p2', '32884.p2', '22452.p2', '232519.p2', '418234.p2']
# ITERATION IN 0
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 215081. Max(delW):   0.000027	Max(delU):   0.000008
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# 247517. Max(delW):   0.000023	Max(delU):   0.000008
# ITERATION IN 1
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 215081. Max(delW):   0.000027	Max(delU):   0.000008
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 2
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 3
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 4
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 5
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 6
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 7
# 2178. Max(delW):   0.000014	Max(delU):   0.000002
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 8
# 2178. Max(delW):   0.000014	Max(delU):   0.000003
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# ITERATION IN 9
# 2178. Max(delW):   0.000014	Max(delU):   0.000003
# 425273. Max(delW):   0.000047	Max(delU):   0.000003
# Batch:  107
# ['81610.p2', '263010.p2', '110869.p2', '68239.p2', '29016.p2', '28616.p2', '136675.p2', '18388.p2', '310370.p2', '369427.p2', '139403.p2', '59158.p2', '60656.p2', '324852.p2', '189874.p2', '152008.p2', '286222.p2', '33541.p2', '2681.p2', '26145.p2']
# ITERATION IN 0
# 310370. 286222. Max(delW):   0.000047	Max(delU):   0.000008
# 2681. Max(delW):   0.000045	Max(delU):   0.000012
# ITERATION IN 1
# 310370. 286222. Max(delW):   0.000047	Max(delU):   0.000008
# 2681. Max(delW):   0.000045	Max(delU):   0.000012
# ITERATION IN 2
# 310370. 2681. Max(delW):   0.000045	Max(delU):   0.000012
# ITERATION IN 3
# 310370. 2681. Max(delW):   0.000045	Max(delU):   0.000012
# ITERATION IN 4
# 310370. 2681. Max(delW):   0.000047	Max(delU):   0.000012
# ITERATION IN 5
# 310370. 2681. Max(delW):   0.000045	Max(delU):   0.000013
# ITERATION IN 6
# 310370. 2681. Max(delW):   0.000045	Max(delU):   0.000013
# ITERATION IN 7
# 310370. 2681. Max(delW):   0.000045	Max(delU):   0.000013
# ITERATION IN 8
# 310370. 2681. Max(delW):   0.000045	Max(delU):   0.000013
# ITERATION IN 9
# 310370. 2681. Max(delW):   0.000045	Max(delU):   0.000014
# Batch:  108
# ['213236.p2', '165121.p2', '42504.p2', '416828.p2', '231298.p2', '334061.p2', '89068.p2', '2479.p2', '219223.p2', '33860.p2', '416674.p2', '372957.p2', '201483.p2', '308926.p2', '122084.p2', '315357.p2', '365964.p2', '325264.p2', '125078.p2', '32400.p2']
# ITERATION IN 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-682f3cf3fbd9> in <module>()
#       1 # Complete Training
#       2 trainingStatus = defaultdict(lambda: bool(False)) # Reset it after 3 epochs of full-training set
# ----> 3 train(loaded_SKT, loaded_DCS, 3000)
#       4 playBeep()
#
# <ipython-input-10-ad4d95245de8> in train(loaded_SKT, loaded_DCS, n_trainset)
#      32                 # trainer.Save('outputs/saved_trainer.p')
#      33                 try:
# ---> 34                     trainer.Train(sentenceObj, dcsObj)
#      35                 except (IndexError, KeyError) as e:
#      36                     print('\x1bFailed: {} \x1b'.format(sentenceObj.sent_id))
#
# <ipython-input-12-86099a0b60c0> in Train(self, sentenceObj, dcsObj)
#     170             (conflicts_Dict, featVMat, WScalarMat, SigmoidGateOutput) = GetGraph(nodelist, self.neuralnet)
#     171         else:
# --> 172             (conflicts_Dict, featVMat, WScalarMat) = GetGraph(nodelist, self.neuralnet)
#     173         Total_Loss = 0
#     174
#
# <ipython-input-7-8b8230b98478> in GetGraph(nodelist, neuralnet)
#      45         conflicts_Dict = Get_Conflicts(nodelist)
#      46
# ---> 47         featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)
#      48
#      49         WScalarMat = Get_W_Scalar_Matrix_from_FeatVect_Matrix(featVMat, nodelist, conflicts_Dict, neuralnet)
#
# D:\Users\Bishal Santra\Documents\Sanskrit_Project\Bishal\Clean_n_clear\word_definite.py in Get_Feat_Vec_Matrix(nodelist_new, conflicts_Dict)
#     393                 pass
#     394             else:
# --> 395                 featVMat[i][j] = Get_Features(nodelist_new[i], nodelist_new[j])
#     396     return featVMat
#     397
#
# D:\Users\Bishal Santra\Documents\Sanskrit_Project\Bishal\Clean_n_clear\word_definite.py in Get_Features(node1, node2)
#    6419     feats[fIndex] = pleft * pmid * pright; fIndex += 1
#    6420
# -> 6421     feats[feats < 1e-25] = 1e-25
#    6422     return -np.log10(feats)
#    6423
#
# KeyboardInterrupt:

# %%
# Test on training set
test(loaded_SKT, loaded_DCS, n_testSet=1000, _testFiles=TrainFiles)
playBeep()
# Out:
# 0  Checkpoint...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-88715f086c0e> in <module>()
#       1 # Test on training set
# ----> 2 test(loaded_SKT, loaded_DCS, n_testSet=1000, _testFiles=TrainFiles)
#       3 playBeep()
#
# <ipython-input-10-ad4d95245de8> in test(loaded_SKT, loaded_DCS, n_testSet, _testFiles, old_Tester)
#      70                 (word_match, lemma_match, n_dcsWords, n_output_nodes) = trainer.Test_Old(sentenceObj, dcsObj)
#      71             else:
# ---> 72                 (word_match, lemma_match, n_dcsWords, n_output_nodes) = trainer.Test(sentenceObj, dcsObj)
#      73
#      74             recalls.append(lemma_match/n_dcsWords)
#
# <ipython-input-12-86099a0b60c0> in Test(self, sentenceObj, dcsObj)
#      77         minMst = None
#      78         try:
# ---> 79             (nodelist, nodelist_correct, _) = GetTrainingKit(sentenceObj, dcsObj)
#      80             # nodelist = GetNodes(sentenceObj)
#      81         except IndexError:
#
# <ipython-input-7-8b8230b98478> in GetTrainingKit(sentenceObj, dcsObj)
#      10 """
#      11 def GetTrainingKit(sentenceObj, dcsObj):
# ---> 12     nodelist = GetNodes(sentenceObj)
#      13
#      14     # Nodelist with only the correct_nodes
#
# D:\Users\Bishal Santra\Documents\Sanskrit_Project\Bishal\Clean_n_clear\word_definite.py in GetNodes(sentenceObj)
#      62                             cng_x = cng_list[x]
#      63                             nodelist[node_id] = word_definite(
# ---> 64                                 rom_slp(word.names),
#      65                                 rom_slp(word.lemmas[lemma_i]),
#      66                                 cng_x, word_pos, chunk_id
#
# D:\Users\Bishal Santra\Documents\Sanskrit_Project\Bishal\Clean_n_clear\romtoslp.py in rom_slp(a)
#      11
#      12     double_dict={}
# ---> 13     f=open('rom2.txt','r', encoding = u'utf8')
#      14     for lines in f.readlines():
#      15             words=lines.split(',')
#
# d:\program files\anaconda3\lib\codecs.py in __init__(self, errors)
#     306     byte sequences.
#     307     """
# --> 308     def __init__(self, errors='strict'):
#     309         IncrementalDecoder.__init__(self, errors)
#     310         # undecoded input that is kept between calls to decode()
#
# KeyboardInterrupt:

# %%
start = time.clock()
_recalls, _recalls_of_word, _precisions, _precisions_of_words = test(loaded_SKT, loaded_DCS, n_testSet = 1000, old_Tester=True)
time_taken_2 = (time.clock() - start)
# print('T1: {}:{}, T2: {}:{}'.format(math.floor(time_taken_1/60), time_taken_1 % 60, math.floor(time_taken_2/60), time_taken_2 % 60))
playBeep()
# Out:
# 0  Checkpoint...
# 100  Checkpoint...
# 200  Checkpoint...
# 300  Checkpoint...
# 400  Checkpoint...
# 500  Checkpoint...
# 600  Checkpoint...
# 700  Checkpoint...
# 800  Checkpoint...
# 900  Checkpoint...
# Micro Recall[lemma]: 79.84289313769082
# Micro Recall[word]: 66.35541722246924
#
# Micro Precision[lemma]: 67.95761322063832
# Micro Precision[word]: 56.47786047685127
#
# Avg. Recall of Lemmas: 0.7885403568735188
# Avg. Recall of Words: 0.6508489523629964
# Avg. Precision of Lemmas: 0.7021412515775133
# Avg. Precision of Words: 0.5810045938180612

# %%
# Test on Larger Set
_recalls, _recalls_of_word, _precisions, _precisions_of_words =\
test(loaded_SKT, loaded_DCS, n_testSet = 2000,  _testFiles = TestFiles_2, old_Tester=True)
playBeep()
# Out:
# 0  Checkpoint...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-493e75bc24e1> in <module>()
#       1 # Test on Larger Set
# ----> 2 _recalls, _recalls_of_word, _precisions, _precisions_of_words =test(loaded_SKT, loaded_DCS, n_testSet = 2000,  _testFiles = TestFiles_2, old_Tester=True)
#       3 playBeep()
#
# <ipython-input-10-ad4d95245de8> in test(loaded_SKT, loaded_DCS, n_testSet, _testFiles, old_Tester)
#      68         try:
#      69             if old_Tester:
# ---> 70                 (word_match, lemma_match, n_dcsWords, n_output_nodes) = trainer.Test_Old(sentenceObj, dcsObj)
#      71             else:
#      72                 (word_match, lemma_match, n_dcsWords, n_output_nodes) = trainer.Test(sentenceObj, dcsObj)
#
# <ipython-input-12-86099a0b60c0> in Test_Old(self, sentenceObj, dcsObj)
#      34         conflicts_Dict_correct = Get_Conflicts(nodelist_correct)
#      35
# ---> 36         featVMat = Get_Feat_Vec_Matrix(nodelist, conflicts_Dict)
#      37         featVMat_correct = Get_Feat_Vec_Matrix(nodelist_correct, conflicts_Dict_correct)
#      38
#
# D:\Users\Bishal Santra\Documents\Sanskrit_Project\Bishal\Clean_n_clear\word_definite.py in Get_Feat_Vec_Matrix(nodelist_new, conflicts_Dict)
#     393                 pass
#     394             else:
# --> 395                 featVMat[i][j] = Get_Features(nodelist_new[i], nodelist_new[j])
#     396     return featVMat
#     397
#
# D:\Users\Bishal Santra\Documents\Sanskrit_Project\Bishal\Clean_n_clear\word_definite.py in Get_Features(node1, node2)
#    6420
#    6421     feats[feats < 1e-25] = 1e-25
# -> 6422     return -np.log10(feats)
#    6423
#
# KeyboardInterrupt:

# %%
# POST TEST 1K SET
# start = time.clock()
# test(loaded_SKT, loaded_DCS, n_testSet = 1000)
# time_taken_1 = (time.clock() - start)

# %%
print(p_name)
pickle.dump({
        'U': trainer.neuralnet.U,
        'W': trainer.neuralnet.W,
        'n': trainer.neuralnet.n,
        'd': trainer.neuralnet.d
    }, open(p_name, 'wb'))
# Out:
# outputs/train_nnet_t9780486603433.p

# %%
trainer.neuralnet.W
# Out:
# array([[ 0.00722495,  0.00338938,  0.00176284, ...,  0.009796  ,
#          0.0068291 , -0.00310815],
#        [ 0.00205929, -0.00027124, -0.00189266, ...,  0.00036876,
#         -0.00670928,  0.01044982],
#        [-0.00470419,  0.00519006, -0.00487317, ...,  0.00630901,
#          0.00631652, -0.0028062 ],
#        ...,
#        [-0.00981885, -0.00075694,  0.00930562, ..., -0.0052305 ,
#         -0.00142855,  0.00257117],
#        [-0.00283655,  0.00643924, -0.00442686, ...,  0.00092071,
#         -0.00016554, -0.00016706],
#        [-0.00847906, -0.00114583,  0.00118957, ..., -0.00622475,
#          0.0050656 , -0.00734032]])

# %%
trainer.neuralnet.U
# Out:
# array([[ 0.04898352],
#        [ 0.07198067],
#        [ 0.04638693],
#        [ 0.02759166],
#        [ 0.08254517],
#        [-0.08328421],
#        [-0.03602132],
#        [-0.04564724],
#        [ 0.05644355],
#        [-0.03174373],
#        [-0.05054378],
#        [-0.01256383],
#        [ 0.06218375],
#        [ 0.07763085],
#        [-0.09395439],
#        [-0.05032174],
#        [-0.06160398],
#        [-0.04385358],
#        [ 0.03797409],
#        [ 0.02710784],
#        [ 0.06879289],
#        [-0.02271876],
#        [-0.0960755 ],
#        [-0.01852471],
#        [ 0.07529398],
#        [ 0.04353588],
#        [ 0.05879214],
#        [ 0.09574614],
#        [ 0.03866831],
#        [-0.08346177],
#        [-0.01153538],
#        [-0.03091819],
#        [-0.01030404],
#        [ 0.05507836],
#        [-0.02011198],
#        [ 0.01430288],
#        [-0.03512014],
#        [-0.01738083],
#        [ 0.09215843],
#        [-0.08607582],
#        [ 0.08938146],
#        [-0.07966959],
#        [ 0.06414074],
#        [ 0.06171342],
#        [ 0.0094823 ],
#        [-0.01281583],
#        [-0.03365521],
#        [-0.07455252],
#        [-0.06672022],
#        [ 0.04170644],
#        [-0.01213847],
#        [ 0.06018671],
#        [-0.01956383],
#        [ 0.08912705],
#        [-0.02644472],
#        [ 0.00663482],
#        [ 0.07361999],
#        [-0.09676907],
#        [-0.08297686],
#        [-0.08440374],
#        [-0.00637524],
#        [-0.0708681 ],
#        [-0.05311092],
#        [-0.04503221],
#        [-0.07224146],
#        [ 0.01994653],
#        [-0.07724085],
#        [-0.05888359],
#        [ 0.05324637],
#        [-0.0093105 ],
#        [-0.03204649],
#        [ 0.07210608],
#        [-0.04640202],
#        [ 0.01354811],
#        [-0.00059053],
#        [ 0.06600521],
#        [-0.0303179 ],
#        [ 0.01523406],
#        [ 0.05631443],
#        [ 0.03676402],
#        [-0.02431828],
#        [ 0.01269311],
#        [ 0.05707825],
#        [-0.01314767],
#        [-0.04528545],
#        [ 0.04721412],
#        [-0.04697049],
#        [-0.09920036],
#        [ 0.08893998],
#        [-0.09154902],
#        [-0.0087497 ],
#        [-0.08566303],
#        [-0.0819315 ],
#        [ 0.09797152],
#        [-0.05274764],
#        [ 0.04352427],
#        [ 0.01546146],
#        [ 0.02439296],
#        [-0.08646945],
#        [-0.04149545],
#        [ 0.01884514],
#        [ 0.03457191],
#        [-0.00885316],
#        [ 0.03183832],
#        [ 0.03708231],
#        [-0.05091888],
#        [ 0.01284229],
#        [-0.05013382],
#        [ 0.04292727],
#        [-0.07790512],
#        [-0.06394862],
#        [-0.0810167 ],
#        [ 0.07102292],
#        [-0.03941343],
#        [ 0.05205652],
#        [ 0.05565455],
#        [-0.06818426],
#        [ 0.03732678],
#        [ 0.01792271],
#        [ 0.08819267],
#        [-0.05844136],
#        [-0.07030777],
#        [ 0.01366739],
#        [ 0.09080418],
#        [-0.00929164],
#        [-0.02197151],
#        [ 0.0509208 ],
#        [ 0.04164526],
#        [-0.09786649],
#        [ 0.02963007],
#        [ 0.02565233],
#        [ 0.00404706],
#        [-0.07715929],
#        [-0.0052132 ],
#        [ 0.08135153],
#        [ 0.05504393],
#        [-0.03521443],
#        [ 0.09702746],
#        [-0.09443001],
#        [-0.05035182],
#        [ 0.0785294 ],
#        [-0.07768039],
#        [-0.01490147],
#        [-0.00355805],
#        [ 0.04935324],
#        [-0.0163436 ],
#        [ 0.00468124],
#        [ 0.07474928],
#        [-0.06895269],
#        [ 0.07631883],
#        [ 0.04436917],
#        [ 0.08388379],
#        [-0.07269289],
#        [ 0.07117312],
#        [ 0.04019123],
#        [-0.09723692],
#        [ 0.01157334],
#        [-0.0832809 ],
#        [ 0.01692387],
#        [ 0.09383059],
#        [-0.01694272],
#        [-0.07627642],
#        [-0.03266236],
#        [-0.08603256],
#        [-0.03475228],
#        [ 0.0722679 ],
#        [ 0.09733542],
#        [-0.08031955],
#        [ 0.0934579 ],
#        [ 0.0645308 ],
#        [ 0.02074543],
#        [ 0.06127709],
#        [ 0.08911726],
#        [ 0.06601052],
#        [-0.06109684],
#        [-0.03933345],
#        [-0.03815634],
#        [ 0.04600707],
#        [ 0.01115821],
#        [-0.0300081 ],
#        [-0.03859269],
#        [ 0.02237371],
#        [ 0.05235781],
#        [ 0.03921854],
#        [-0.0786361 ],
#        [-0.00381443],
#        [-0.08344232],
#        [ 0.06307715],
#        [ 0.03708593],
#        [-0.07247071],
#        [ 0.00903452],
#        [ 0.05936712],
#        [-0.04028409],
#        [-0.04658019],
#        [-0.08268174],
#        [-0.08217022],
#        [ 0.00645996],
#        [-0.02619096],
#        [-0.04809406],
#        [ 0.00172911],
#        [ 0.05561509],
#        [ 0.04808042],
#        [-0.0554712 ],
#        [-0.00252318],
#        [ 0.0133713 ],
#        [ 0.08614316],
#        [-0.0336869 ],
#        [-0.02655318],
#        [-0.08629506],
#        [-0.05254013],
#        [ 0.06284451],
#        [ 0.02085899],
#        [-0.00348133],
#        [-0.05476431],
#        [-0.06896119],
#        [-0.05650307],
#        [-0.03045535],
#        [-0.08565618],
#        [-0.05730464],
#        [ 0.03337427],
#        [ 0.00443259],
#        [-0.03268453],
#        [-0.00418472],
#        [-0.0301064 ],
#        [ 0.01849558],
#        [ 0.02032435],
#        [ 0.04470735],
#        [ 0.07492118],
#        [ 0.01160942],
#        [ 0.08592295],
#        [ 0.04077896],
#        [ 0.04340235],
#        [ 0.00708311],
#        [-0.0784674 ],
#        [-0.03758362],
#        [-0.00963596],
#        [-0.09140396],
#        [-0.02148803],
#        [-0.02466671],
#        [ 0.0710625 ],
#        [-0.08981015],
#        [-0.03896634],
#        [ 0.09732412],
#        [ 0.03999505],
#        [ 0.08509618],
#        [-0.02637306],
#        [-0.09444673],
#        [ 0.03085057],
#        [-0.0613951 ],
#        [ 0.07078048],
#        [ 0.08945628],
#        [-0.08995902],
#        [ 0.07065856],
#        [ 0.0851062 ],
#        [-0.08757518],
#        [ 0.00268327],
#        [ 0.00803085],
#        [-0.09491545],
#        [ 0.04842671],
#        [ 0.06277233],
#        [-0.03145965],
#        [ 0.02129835],
#        [ 0.05799351],
#        [ 0.00052018],
#        [ 0.04947628],
#        [-0.02818988],
#        [ 0.06879002],
#        [ 0.06948918],
#        [ 0.07630612],
#        [ 0.01887511],
#        [-0.08693109],
#        [-0.01664019],
#        [ 0.05701192],
#        [ 0.08120864],
#        [-0.07536017],
#        [ 0.05574385],
#        [ 0.03516349],
#        [ 0.08175953],
#        [-0.05874985],
#        [-0.06215628],
#        [ 0.01461686],
#        [ 0.06874234],
#        [ 0.00596053],
#        [-0.04749437],
#        [ 0.04113275],
#        [ 0.07687755],
#        [ 0.08951695],
#        [ 0.07561901],
#        [-0.00955271],
#        [-0.08214804],
#        [-0.09303553],
#        [-0.07517688],
#        [-0.07547476],
#        [ 0.07146087],
#        [-0.03326984],
#        [-0.03073812],
#        [-0.01060653],
#        [ 0.08039954],
#        [-0.07963312],
#        [-0.00767288],
#        [-0.09254094],
#        [ 0.03733766],
#        [ 0.02380098],
#        [ 0.04308315],
#        [-0.08507613],
#        [-0.03544313],
#        [ 0.03866965],
#        [-0.08375587],
#        [-0.02195501],
#        [-0.01011562],
#        [ 0.0527529 ],
#        [-0.098432  ],
#        [ 0.06192188],
#        [ 0.00817625],
#        [-0.07339823],
#        [-0.08220971],
#        [ 0.06054786],
#        [-0.04089243],
#        [ 0.09731612],
#        [-0.07353625],
#        [-0.09840369],
#        [-0.04450139],
#        [-0.08894133],
#        [ 0.04959497],
#        [ 0.07540301],
#        [ 0.07582247],
#        [ 0.09357045],
#        [ 0.00634279],
#        [ 0.03378873],
#        [-0.02144328],
#        [ 0.06875719],
#        [ 0.02849649],
#        [-0.04989146],
#        [-0.01501048],
#        [-0.02495499],
#        [ 0.08609066],
#        [ 0.04844598],
#        [ 0.09205663],
#        [-0.07290737],
#        [-0.04246744],
#        [ 0.01615399],
#        [ 0.02062623],
#        [ 0.02215287],
#        [-0.09055569],
#        [ 0.09822767],
#        [-0.09415662],
#        [-0.08493618],
#        [ 0.01789279],
#        [-0.03253135],
#        [-0.04462653],
#        [-0.0881115 ],
#        [-0.09129662],
#        [-0.08419157],
#        [ 0.03236949],
#        [ 0.07319768],
#        [-0.07627869],
#        [-0.01654381],
#        [-0.07113032],
#        [ 0.04592464],
#        [-0.04928269],
#        [-0.02733231],
#        [-0.09617139],
#        [-0.09714357],
#        [ 0.06721621],
#        [ 0.00348471],
#        [-0.09046826],
#        [ 0.09693564],
#        [ 0.09403288],
#        [ 0.01618206],
#        [-0.07802412],
#        [ 0.02651664],
#        [ 0.07524987],
#        [-0.03396731],
#        [ 0.02103224],
#        [ 0.06571322],
#        [-0.03108887],
#        [-0.01298159],
#        [-0.04297073],
#        [-0.07920211],
#        [-0.00870807],
#        [ 0.06957339],
#        [ 0.01273107],
#        [ 0.05448161],
#        [-0.0732349 ],
#        [ 0.08484406],
#        [-0.01013188],
#        [-0.02592514],
#        [ 0.09366659],
#        [-0.02153435],
#        [ 0.0503251 ],
#        [ 0.02122458],
#        [-0.08706826],
#        [-0.0926977 ],
#        [ 0.07746902],
#        [-0.05519993],
#        [-0.04080805],
#        [-0.01264538],
#        [-0.02972362],
#        [-0.07202041],
#        [ 0.02053519]])

# %%
# Out:
# 0.49675855746328523

# %%
aa.remove(1)

# %%
# Out:
# [0, 2, 3, 4, 5, 6, 7, 8, 9]
